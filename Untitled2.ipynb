# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
clus0_100 = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus1_100 = np.load('necro_pars10k_cluster1_5720_mod.npy')
clus2_100 = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus3_100 = np.load('necro_pars10k_cluster3_5720_mod.npy')

# %%
tspan = np.linspace(0, 1800, 500)
m = model100.components

# %%
solverwt0 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
wtclus0 = solverwt0.run(param_values=clus0_100, num_processors = 20)
c0df100wt = wtclus0.dataframe
# Out:
# 2021-05-13 11:57:29.854 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 11:57:30.617 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 11:57:30.740 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 11:57:30.965 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:01:50.395 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:01:50.398 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:01:52.228 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solverwt1 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
wtclus1 = solverwt1.run(param_values=clus1_100, num_processors = 20)
c1df100wt = wtclus1.dataframe
# Out:
# 2021-05-13 12:01:55.171 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:01:55.176 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:01:55.210 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:01:55.312 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:02:51.553 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:02:51.554 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:02:52.417 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solverwt2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
wtclus2 = solverwt2.run(param_values=clus2_100, num_processors = 20)
c2df100wt = wtclus2.dataframe
# Out:
# 2021-05-13 12:02:53.655 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:02:53.660 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:02:53.693 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:02:53.820 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:04:28.136 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:04:28.138 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:04:29.257 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solverwt3 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
wtclus3 = solverwt3.run(param_values=clus3_100, num_processors = 20)
c3df100wt = wtclus3.dataframe
# Out:
# 2021-05-13 12:04:30.949 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:04:30.955 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:04:30.988 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:04:31.154 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:07:17.655 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:07:17.659 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:07:19.259 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvera200 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
a20clus0 = solvera200.run(initials = {m.FADD(bDD=None, bDED1=None, bDED2=None):933},
                         param_values=clus0_100, num_processors = 20)
c0df100a20 = a20clus0.dataframe
# Out:
# 2021-05-13 12:07:21.669 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:07:21.674 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:07:21.708 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:07:21.900 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:11:30.798 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:11:30.800 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:11:32.700 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvera201 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
a20clus1 = solvera201.run(initials = {m.FADD(bDD=None, bDED1=None, bDED2=None):933},
                         param_values=clus1_100, num_processors = 20)
c1df100a20 = a20clus1.dataframe
# Out:
# 2021-05-13 12:11:35.834 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:11:35.840 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:11:35.877 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:11:35.974 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:12:32.135 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:12:32.136 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:12:33.077 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvera202 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
a20clus2 = solvera202.run(initials = {m.FADD(bDD=None, bDED1=None, bDED2=None):933},
                         param_values=clus2_100, num_processors = 20)
c2df100a20 = a20clus2.dataframe
# Out:
# 2021-05-13 12:12:34.326 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:12:34.331 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:12:34.364 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:12:34.484 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:14:06.824 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:14:06.828 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:14:07.957 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvera203 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
a20clus3 = solvera203.run(initials = {m.FADD(bDD=None, bDED1=None, bDED2=None):933},
                         param_values=clus3_100, num_processors = 20)
c3df100a20 = a20clus3.dataframe
# Out:
# 2021-05-13 12:14:09.637 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 12:14:09.642 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 12:14:09.676 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 12:14:09.831 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 12:16:46.301 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 12:16:46.303 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 12:16:47.932 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure()
for n in range(len(clus1_100)):
    plt.plot(tspan/60, c1df100wt.loc[n]['MLKLa_obs'].iloc[:], lw=1.5, color ='blue', zorder = 1, alpha = 0.7)
    plt.plot(tspan/60, c1df100a20.loc[n]['MLKLa_obs'].iloc[:], lw=1.5, color ='red', zorder = 1, alpha = 0.7)
plt.show()

# %%
x1001 = np.array([0, 30, 90, 270])
x1002 = np.array([480, 720, 960])
y1001 = np.array([0, 0.00885691708746097,0.0161886154261265,0.0373005242261882])
y1002 = np.array([0.2798939020159581, .7797294067, .98])

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus0_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, c0df100wt.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.7)
    ax1.plot(tspan/60, c0df100a20.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='red', zorder = 1, alpha = 0.7)

    ax1.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax1.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 24)
    ax1.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus1_100)):
#     ax2.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label= '50% pMLKL')
    ax2.plot(tspan/60, c1df100wt.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax2.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax2.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 24)
    ax2.set_ylim(ymin = 0)
    ax2.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, c2df100wt.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
    ax3.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax3.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 24)
    ax3.set_ylim(ymin = 0)
    ax3.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
for n in range(len(clus3_100)):
    plt.plot(tspan/60, c3df100wt.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax4.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax4.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 24)
    ax4.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of WT pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus0_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, c0df100a20.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax1.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax1.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 24)
    ax1.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus1_100)):
#     ax2.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label= '50% pMLKL')
    ax2.plot(tspan/60, c1df100a20.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax2.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax2.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 24)
    ax2.set_ylim(ymin = 0)
    ax2.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, c2df100a20.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
    ax3.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax3.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 24)
    ax3.set_ylim(ymin = 0)
    ax3.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
for n in range(len(clus3_100)):
    plt.plot(tspan/60, c3df100a20.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax4.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax4.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 24)
    ax4.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of A20 pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
solvertd0 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
tdclus0 = solvertd0.run(initials = {m.TRADD(brec=None, brip=None, state='unmod', bDD1 = None, bDD2 = None):1408},
                         param_values=clus0_100, num_processors = 20)
c0df100td = tdclus0.dataframe
# Out:
# 2021-05-13 13:31:22.981 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 13:31:22.993 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 13:31:23.063 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 13:31:23.286 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 13:35:37.152 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 13:35:37.153 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 13:35:39.046 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvertd1 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
tdclus1 = solvertd1.run(initials = {m.TRADD(brec=None, brip=None, state='unmod', bDD1 = None, bDD2 = None):1408},
                         param_values=clus1_100, num_processors = 20)
c1df100td = tdclus1.dataframe
# Out:
# 2021-05-13 13:35:42.114 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 13:35:42.119 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 13:35:42.152 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 13:35:42.251 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 13:36:41.642 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 13:36:41.644 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 13:36:42.484 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvertd2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
tdclus2 = solvertd2.run(initials = {m.TRADD(brec=None, brip=None, state='unmod', bDD1 = None, bDD2 = None):1408},
                         param_values=clus2_100, num_processors = 20)
c2df100td = tdclus2.dataframe
# Out:
# 2021-05-13 13:36:43.764 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 13:36:43.769 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 13:36:43.802 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 13:36:43.922 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 13:38:18.215 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 13:38:18.217 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 13:38:19.320 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solvertd3 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
tdclus3 = solvertd3.run(initials = {m.TRADD(brec=None, brip=None, state='unmod', bDD1 = None, bDD2 = None):1408},
                         param_values=clus3_100, num_processors = 20)
c3df100td = tdclus3.dataframe
# Out:
# 2021-05-13 13:38:21.087 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2021-05-13 13:38:21.092 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2021-05-13 13:38:21.126 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2021-05-13 13:38:21.284 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2021-05-13 13:41:03.342 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2021-05-13 13:41:03.343 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2021-05-13 13:41:04.822 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus0_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, c0df100td.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax1.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax1.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 24)
    ax1.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus1_100)):
#     ax2.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label= '50% pMLKL')
    ax2.plot(tspan/60, c1df100td.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax2.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax2.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 24)
    ax2.set_ylim(ymin = 0)
    ax2.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, c2df100td.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
    ax3.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax3.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 24)
    ax3.set_ylim(ymin = 0)
    ax3.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
for n in range(len(clus3_100)):
    plt.plot(tspan/60, c3df100td.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax4.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax4.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 24)
    ax4.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='red', lw=4)]
    ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of TRADD pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()
