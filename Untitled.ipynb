# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
par_files = np.load('necro_pars10k_allclusmod.npy')

# %%
m = model100.components

# %%
tspan = np.linspace(0, 1800, 500)
solver10 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result10 = solver10.run(initials = {m.TNF(brec=None):233}, param_values=par_files, num_processors = 20)
df10 = result10.dataframe
# Out:
# 2020-10-26 22:29:37.544 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-26 22:29:38.359 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-26 22:29:38.482 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-26 22:29:39.007 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-10-26 22:57:26.100 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-26 22:57:26.102 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-26 22:57:30.704 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure()
for n in range(len(par_files)):
    plt.plot(tspan/60, df10.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
#     plt.set_xlim(xmin = 0, xmax = 24)
#     plt.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
plt.show()

# %%
plt.figure()
for n in range(len(par_files)):
    plt.plot(tspan/60, df10.loc[n]['Flipi_obs'].iloc[:]/3900, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
#     plt.set_xlim(xmin = 0, xmax = 24)
#     plt.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
plt.show()
