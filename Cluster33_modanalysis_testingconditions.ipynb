# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
for i,pr in enumerate(model100.parameters):
    print(i,":",pr)
# Out:
# 0 : Parameter('TNF_0', 2326.0)
# 1 : Parameter('TNFR_0', 4800.0)
# 2 : Parameter('TRADD_0', 4696.0)
# 3 : Parameter('RIP1_0', 40000.0)
# 4 : Parameter('TRAF_0', 11776.0)
# 5 : Parameter('cIAP_0', 9000.0)
# 6 : Parameter('A20_0', 9000.0)
# 7 : Parameter('CYLD_0', 9000.0)
# 8 : Parameter('FADD_0', 3109.0)
# 9 : Parameter('flip_L_0', 3900.0)
# 10 : Parameter('Lubac_0', 7226.0)
# 11 : Parameter('C8_0', 3799.0)
# 12 : Parameter('RIP3_0', 10654.0)
# 13 : Parameter('MLKLa_0', 5544.0)
# 14 : Parameter('p1f', 1e-06)
# 15 : Parameter('p1r', 0.001)
# 16 : Parameter('p2f', 0.001)
# 17 : Parameter('p3f', 1e-06)
# 18 : Parameter('p3r', 0.001)
# 19 : Parameter('p4f', 1e-06)
# 20 : Parameter('p4r', 0.001)
# 21 : Parameter('p5f', 1e-06)
# 22 : Parameter('p5r', 0.001)
# 23 : Parameter('p6f', 1e-06)
# 24 : Parameter('p6r', 0.001)
# 25 : Parameter('p7f', 0.1)
# 26 : Parameter('p8f', 1e-06)
# 27 : Parameter('p8r', 0.001)
# 28 : Parameter('p9f', 1e-06)
# 29 : Parameter('p9r', 0.001)
# 30 : Parameter('p10f', 0.1)
# 31 : Parameter('p11f', 1e-06)
# 32 : Parameter('p11r', 0.001)
# 33 : Parameter('p12f', 0.1)
# 34 : Parameter('p13f', 0.1)
# 35 : Parameter('p13r', 3.11e-07)
# 36 : Parameter('p14f', 3.27e-06)
# 37 : Parameter('p14r', 0.018)
# 38 : Parameter('p15f', 3.27e-06)
# 39 : Parameter('p15r', 0.018)
# 40 : Parameter('p16f', 0.0327)
# 41 : Parameter('p16r', 0.018)
# 42 : Parameter('p17f', 1e-06)
# 43 : Parameter('p18f', 1e-06)
# 44 : Parameter('p18r', 0.001)
# 45 : Parameter('p19f', 0.1)
# 46 : Parameter('p20f', 0.01)
# 47 : Parameter('p20r', 0.001)
# 48 : Parameter('p21f', 0.001)
# 49 : Parameter('p22f', 1e-06)
# 50 : Parameter('p23f', 1.0)
# 51 : Parameter('p24f', 1e-06)
# 52 : Parameter('p24r', 0.001)
# 53 : Parameter('p25f', 1e-06)

# %%
par_files = np.load('necro_pars10k_allclusmod.npy')

# %%
clus3_100 = np.load('necro_pars10k_cluster3_5720_mod.npy')

# %%
clus3mod = clus3_100[:][:,14:]

# %%
idx = list(range(14, 54,1)) #index for parameter values after initial conditions 14-50
print(len(idx))
counter = 0
# samples_nonlog = 10 ** samples
ndims = len(idx)
plt.figure(figsize=(20, 20))
for i in range(1,41):
    plt.subplot(8, 5, i)
    # plt.plot(samples[:, counter])
#     sns.distplot(norm.rvs(size=n, loc=logps_vals[counter], scale=scaling[counter]), color='cyan')
    sns.distplot(clus3mod[:][:, counter], color = 'red')
    sns.distplot(clus3mod[sim_idx_to_keep][:][:, counter])
    plt.title(model100.parameters[idx[counter]].name, fontdict={'fontsize': 10})
    counter += 1
    plt.xlabel("Log(10) Value", fontsize=10)
    plt.ylabel("Probability", fontsize=9, labelpad=15)
    plt.xlim(xmin = -1,xmax=10)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.6)
# plt.savefig('pydream_priorpost_traceplot_earm_gi.pdf', format='pdf', bbox_inches="tight")
plt.show()
# Out:
# 40

# %%
clus3_100n = np.load('necro_pars10k_cluster3_5720_mod.npy')
clus3_100nn = np.load('necro_pars10k_cluster3_5720_mod.npy')
clus3_100nnn = np.load('necro_pars10k_cluster3_5720_mod.npy')
# clus3_100nnnn = np.load('necro_pars10k_cluster3_5720_mod.npy')

# %%
g = 47

# %%
a = 30

# %%
p = 14

# %%
clus2_100[:][:,p] = clus2_100[:][:,p]/10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-45620d8d3bd4> in <module>
# ----> 1 clus2_100[:][:,p] = clus2_100[:][:,p]/10
#
# NameError: name 'clus2_100' is not defined

# %%
z = 45

# %%
clus3_100n[:][:,g] = clus3_100n[:][:,g]*10

# %%
clus3_100nn[:][:,g] = clus3_100nn[:][:,g]*100

# %%
clus3_100nnn[:][:,g] = clus3_100nnn[:][:,g]*1000

# %%
clus3_100nnnn[:][:,g] = clus3_100nnnn[:][:,g]*10000

# %%
clus3_100n[:][:,a] = clus3_100n[:][:,a]*10

# %%
clus3_100nn[:][:,a] = clus3_100nn[:][:,a]*100

# %%
clus3_100nnn[:][:,a] = clus3_100nnn[:][:,a]*1000

# %%
clus3_100nnnn[:][:,a] = clus3_100nnnn[:][:,a]*10000

# %%
print(clus2_100n[:][:,p])
print(clus2_100n[:][:,p]/10)
print(clus2_100n[:][:,p]/100)
print(clus2_100n[:][:,p]/1000)

# %%
clus3_100n[:][:,p] = clus3_100n[:][:,p]/100

# %%
clus3_100nn[:][:,p] = clus3_100nn[:][:,p]/100

# %%
clus3_100nnn[:][:,p] = clus3_100nnn[:][:,p]/1000

# %%
clus3_100nnnn[:][:,p] = clus3_100nnnn[:][:,p]/10000

# %%
clus2_100n[:][:,z] = clus2_100n[:][:,z]*10

# %%
clus2_100nn[:][:,z] = clus2_100nn[:][:,z]*100

# %%
clus2_100nnn[:][:,z] = clus2_100nnn[:][:,z]*1000

# %%
clus2_100nnnn[:][:,z] = clus2_100nnnn[:][:,z]*10000

# %%
# fig = plt.figure(figsize=(20, 15))
# for i in range(1,41):
#     ax = fig.add_subplot(8, 5, i)
    # plt.plot(samples[:, counter])
# fig = plt.figure(figsize=(20, 5))
fig, axes = plt.subplots(1, 4, figsize=(28, 7), sharex=True)
plt.subplot(141)
# sns.distplot(clus3_100[:, 42])
sns.distplot(clus3_100[:, 45])
# sns.distplot(clus2_100[:, 48])
# sns.distplot(clus2_100n[:, 45])
# sns.distplot(clus2_100nn[:, 45])
# plt.ylim(ymax=2)
plt.xlim(xmin = -1,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4),
               Line2D([0], [0], color='red', lw=4)]
# plt.legend(custom_lines, [r'$RIP1trunc$',r'$Necro$', 'c8rip3trunc'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)

plt.subplot(142)
# sns.distplot(clus3_100[:, 47])
sns.distplot(clus3_100[:, 48])
# plt.ylim(ymax=4)
# plt.xlim(xmin = -0.5,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8af$',r'$rip3f$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(143)
# sns.distplot(clus2_100[:, 41])
sns.distplot(clus3_100[:, 43])
# sns.distplot(clus2_100[:, 52])
# plt.ylim(ymax=2)
plt.xlim(xmin = -1,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(144)
# sns.distplot(clus2_100[:, 41])
sns.distplot(clus3_100[:, 44])
# sns.distplot(clus2_100[:, 52])
# plt.ylim(ymax=.02)
plt.xlim(xmin = -1,xmax=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
clus2_100[:, 53]

# %%
# fig = plt.figure(figsize=(20, 15))
# for i in range(1,41):
#     ax = fig.add_subplot(8, 5, i)
    # plt.plot(samples[:, counter])
# fig = plt.figure(figsize=(20, 5))
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=True)
plt.subplot(131)
sns.distplot(clus2_100[:, 28])
# sns.distplot(clus2_100[:, 31])
# sns.distplot(clus2_100[:, 45])
# sns.distplot(clus2_100n[:, 45])
# sns.distplot(clus1_100nn[:, 45])
plt.ylim(ymax=0.04)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$RIP1trunc$',r'$Necro$', 'c8rip3trunc'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# 
plt.subplot(132)
sns.distplot(clus2_100[:, 29])
# sns.distplot(clus2_100[:, 32])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8af$',r'$rip3f$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(133)
sns.distplot(clus2_100[:, 30])
# sns.distplot(clus2_100[:, 33])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
x1001 = np.array([0, 30, 90, 270])
x1002 = np.array([480, 720, 960])
y1001 = np.array([0, 0.00885691708746097,0.0161886154261265,0.0373005242261882])
y1002 = np.array([0.2798939020159581, .7797294067, .98])

# %%
m = model100.components

# %%
print(sim_idx_to_keep2)
# Out:
# [0, 2, 7, 10, 11, 14, 18, 24, 25, 29, 30, 36, 37, 38, 39, 40, 41, 47, 48, 54, 58, 67, 69, 70, 73, 76, 77, 78, 80, 81, 87, 88, 89, 90, 96, 97, 100, 102, 103, 107, 108, 110, 117, 118, 120, 121, 122, 123, 125, 127, 130, 133, 134, 136, 140, 143, 148, 150, 152, 154, 156, 159, 161, 163, 166, 167, 170, 171, 173, 175, 177, 180, 184, 190, 191, 192, 195, 199, 204, 205, 206, 212, 217, 219, 220, 221, 225, 226, 229, 231, 233, 234, 235, 236, 237, 240, 242, 247, 248, 252, 253, 255, 257, 258, 263, 265, 270, 272, 273, 275, 278, 279, 282, 283, 285, 287, 288, 292, 295, 297, 298, 299, 302, 304, 305, 306, 308, 310, 312, 313, 315, 317, 318, 319, 325, 327, 331, 332, 333, 338, 341, 343, 347, 353, 356, 357, 358, 359, 360, 361, 363, 365, 366, 368, 372, 373, 377, 378, 382, 383, 387, 389, 390, 394, 398, 400, 402, 404, 411, 412, 415, 417, 419, 422, 423, 424, 426, 427, 428, 429, 430, 432, 433, 434, 440, 443, 449, 453, 454, 455, 457, 458, 459, 461, 463, 468, 469, 470, 473, 474, 481, 485, 486, 488, 489, 491, 492, 493, 495, 496, 498, 500, 506, 508, 513, 515, 518, 524, 525, 526, 528, 534, 536, 537, 538, 544, 546, 548, 550, 552, 553, 556, 559, 564, 570, 571, 572, 577, 578, 579, 580, 581, 582, 584, 587, 590, 591, 596, 599, 600, 602, 603, 605, 609, 611, 613, 614, 621, 628, 630, 632, 634, 641, 646, 654, 655, 660, 664, 666, 667, 672, 673, 674, 680, 682, 687, 688, 689, 690, 691, 697, 699, 700, 703, 708, 709, 711, 712, 715, 716, 717, 718, 721, 722, 726, 727, 728, 730, 734, 735, 737, 739, 740, 743, 746, 747, 753, 758, 760, 765, 766, 767, 770, 773, 778, 779, 780, 781, 788, 795, 799, 800, 802, 805, 808, 809, 814, 817, 823, 825, 835, 837, 839, 841, 842, 844, 845, 846, 848, 849, 851, 852, 853, 858, 859, 860, 861, 864, 865, 868, 871, 874, 877, 892, 896, 897, 900, 901, 905, 907, 908, 909, 910, 911, 915, 928, 929, 935, 940, 941, 942, 943, 944, 947, 948, 950, 953, 956, 958, 960, 962, 965, 966, 967, 969, 970, 972, 975, 976, 977, 980, 982, 984, 987, 988, 991, 993, 995, 1000, 1002, 1004, 1005, 1006, 1008, 1016, 1019, 1021, 1022, 1027, 1028, 1031, 1032, 1034, 1035, 1036, 1038, 1039, 1044, 1046, 1049, 1051, 1053, 1060, 1061, 1062, 1066, 1069, 1071, 1074, 1078, 1079, 1081, 1084, 1088, 1089, 1091, 1098, 1099, 1100, 1104, 1105, 1110, 1115, 1116, 1118, 1120, 1122, 1123, 1124, 1126, 1131, 1133, 1134, 1137, 1141, 1144, 1145, 1147, 1148, 1153, 1155, 1156, 1157, 1161, 1165, 1166, 1170, 1172, 1173, 1175, 1177, 1180, 1181, 1182, 1185, 1190, 1191, 1193, 1197, 1199, 1201, 1202, 1203, 1204, 1216, 1217, 1220, 1221, 1222, 1227, 1229, 1230, 1231, 1232, 1237, 1238, 1245, 1247, 1248, 1250, 1253, 1256, 1257, 1259, 1261, 1262, 1266, 1268, 1270, 1272, 1275, 1278, 1279, 1281, 1282, 1285, 1289, 1292, 1294, 1299, 1300, 1301, 1302, 1303, 1309, 1312, 1314, 1319, 1320, 1324, 1325, 1336, 1337, 1338, 1341, 1345, 1350, 1351, 1354, 1357, 1358, 1359, 1361, 1367, 1369, 1372, 1375, 1376, 1377, 1378, 1379, 1380, 1382, 1387, 1394, 1396, 1400, 1405, 1409, 1415, 1416, 1418, 1419, 1424, 1426, 1429, 1431, 1432, 1435, 1436, 1439, 1441, 1447, 1451, 1452, 1454, 1455, 1456, 1457, 1458, 1467, 1471, 1475, 1476, 1477, 1483, 1485, 1489, 1491, 1497, 1500, 1503, 1504, 1505, 1507, 1513, 1515, 1516, 1518, 1521, 1524, 1527, 1528, 1534, 1538, 1542, 1544, 1545, 1547, 1549, 1550, 1556, 1557, 1560, 1561, 1562, 1566, 1567, 1568, 1574, 1576, 1578, 1579, 1582, 1584, 1585, 1589, 1590, 1595, 1597, 1598, 1599, 1604, 1609, 1613, 1615, 1617, 1618, 1620, 1621, 1623, 1624, 1627, 1628, 1630, 1632, 1637, 1639, 1643, 1644, 1645, 1647, 1650, 1654, 1655, 1658, 1660, 1663, 1664, 1665, 1666, 1668, 1669, 1670, 1672, 1673, 1674, 1675, 1677, 1678, 1680, 1681, 1682, 1689, 1690, 1692, 1693, 1694, 1696, 1701, 1703, 1705, 1707, 1709, 1713, 1714, 1715, 1718, 1720, 1721, 1722, 1723, 1725, 1727, 1733, 1734, 1738, 1743, 1749, 1752, 1754, 1765, 1771, 1774, 1775, 1776, 1777, 1779, 1781, 1782, 1786, 1788, 1789, 1792, 1795, 1796, 1797, 1799, 1801, 1805, 1807, 1811, 1814, 1816, 1821, 1822, 1825, 1829, 1832, 1833, 1835, 1837, 1838, 1841, 1843, 1846, 1848, 1849, 1856, 18 ...

# %%
tspan = np.linspace(0, 1800, 500)
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnn = solver6785nnn.run(param_values=clus3_100, num_processors = 20)
df11 = result6785nnn.dataframe
# Out:
# 2020-11-05 18:00:52.231 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-05 18:00:52.242 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-05 18:00:52.308 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-05 18:00:52.506 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-05 18:03:44.193 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-05 18:03:44.195 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-05 18:03:45.330 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
k =38

# %%
tspan = np.linspace(0, 1800, 500)
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnn = solver6785nnn.run(param_values=clus3_100[k], num_processors = 20)
df1 = result6785nnn.dataframe
# Out:
# 2020-11-15 16:36:10.356 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 16:36:10.368 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 16:36:10.439 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 16:36:10.501 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 16:36:12.256 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 16:36:12.258 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 16:36:12.328 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.A20(brip = None):0},
                            param_values=clus3_100[k], num_processors = 20)
df2 = result3528.dataframe
# Out:
# 2020-11-15 16:36:12.342 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 16:36:12.350 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 16:36:12.400 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 16:36:12.450 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 16:36:14.043 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 16:36:14.045 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 16:36:14.116 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.A20(brip = None):0}
                            , param_values=clus3_100n[k], num_processors = 10)
df3 = result3528.dataframe
# Out:
# 2020-11-15 17:58:27.369 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 17:58:27.381 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 17:58:27.451 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 17:58:27.512 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 17:58:28.518 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 17:58:28.520 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 17:58:28.582 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus3_100nn[k], num_processors = 10)
df4 = result6785n.dataframe
# Out:
# 2020-11-15 17:58:28.596 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 17:58:28.603 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 17:58:28.649 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 17:58:28.697 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 17:58:29.689 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 17:58:29.690 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 17:58:29.726 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus3_100nnn[k], num_processors = 10)
df5 = result6785nn.dataframe
# Out:
# 2020-11-15 17:58:29.735 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 17:58:29.740 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 17:58:29.773 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 17:58:29.814 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 17:58:30.675 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 17:58:30.676 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 17:58:30.722 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus3_100nnnn[k], num_processors = 10)
df6 = result6785nn.dataframe
# Out:
# 2020-11-15 16:37:37.849 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 16:37:37.857 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 16:37:37.909 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 16:37:37.961 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 16:37:38.818 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 16:37:38.819 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 16:37:38.893 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.CYLD(brip=None, btraf = None):0},
                            param_values=clus3_100[k], num_processors = 20)
df22 = result3528.dataframe
# Out:
# 2020-11-04 14:00:10.730 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-04 14:00:10.740 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-04 14:00:10.805 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-04 14:00:10.864 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-04 14:00:11.525 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-04 14:00:11.527 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-04 14:00:11.561 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.CYLD(brip=None, btraf = None):0}
                            , param_values=clus3_100n[k], num_processors = 20)
df33 = result3528.dataframe
# Out:
# 2020-11-15 12:45:57.384 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:45:57.396 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:45:57.471 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:45:57.536 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 12:45:58.768 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:45:58.769 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:45:58.830 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.CYLD(brip=None, btraf = None):0},
                              param_values=clus3_100nn[k], num_processors = 20)
df44 = result6785n.dataframe
# Out:
# 2020-11-15 12:45:58.844 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:45:58.851 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:45:58.898 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:45:58.947 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 12:46:00.378 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:46:00.380 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:46:00.427 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100nnn[k], num_processors = 20)
df55 = result6785nn.dataframe
# Out:
# 2020-11-15 12:46:00.440 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:46:00.446 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:46:00.486 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:46:00.527 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 12:46:01.762 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:46:01.764 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:46:01.827 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100nnnn[k], num_processors = 20)
df665 = result6785nn.dataframe
# Out:
# 2020-11-15 12:46:01.841 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:46:01.848 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:46:01.894 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:46:01.941 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 12:46:03.324 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:46:03.326 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:46:03.389 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=7, color ='steelblue', label = 'A20KO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.plot(tspan, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 3', fontsize=17)
# plt.savefig('figs/Cluster3/pmlkl_100tnf_clus2_5720_A20KO_w24upratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=7, color ='steelblue', label = 'A20KO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 3', fontsize=17)
plt.grid(False)
plt.savefig('figs/Cluster3/pmlkl_100tnf_clus2_5720_A20KO_w24upratemodnogrid.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=6, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w48ratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=7, color ='mediumseagreen', label = 'CYLDKO', zorder = 1, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='mediumseagreen', label = 'CYLDx10', zorder = 1, alpha =  5,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx100',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx1000',zorder = 1, alpha =  5, linestyle = '--')
# plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx10000',zorder = 1, alpha =  5,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 3', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus3_5720_CYLDKO_w30upratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=7, color ='mediumseagreen', label = 'CYLDKO', zorder = 1, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='mediumseagreen', label = 'CYLDx10', zorder = 1, alpha =  5,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx100',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx1000',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx10000',zorder = 1, alpha =  5,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 3', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus3_5720_CYLDKO_w2830upratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=7, color ='mediumseagreen', label = 'CYLDKO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='mediumseagreen', label = 'CYLDx10', zorder = 1, alpha =  5,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx100',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx1000',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx10000',zorder = 1, alpha =  5,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w50dwnratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':') #:
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=6, color ='green', label = 'CYLDKO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='green', label = 'CYLDx10', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx100',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx1000',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx10000',zorder = 1, alpha = 0.7,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w50dwnratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=6, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w47upratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':') #:
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=6, color ='green', label = 'CYLDKO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green', label = 'CYLDx10', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx100',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx1000',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='cyan',  label = 'CYLDx10000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_A20KO_w47upratemod.pdf')
plt.show()

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus3_100, num_processors = 10)
dfa201 = result6785nn.dataframe
# Out:
# 2020-11-15 13:36:33.233 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 13:36:33.245 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 13:36:33.314 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 13:36:33.510 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 13:39:11.405 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 13:39:11.406 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 13:39:12.521 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus3_100n, num_processors = 20)
df6677 = result6785nn.dataframe
# Out:
# 2020-11-15 17:58:40.934 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 17:58:40.945 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 17:58:41.013 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 17:58:41.199 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 18:01:19.872 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 18:01:19.873 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 18:01:21.071 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus3_100nn, num_processors = 20)
df7777 = result6785nn.dataframe
# Out:
# 2020-11-15 18:01:23.322 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 18:01:23.331 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 18:01:23.366 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 18:01:23.532 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 18:04:00.814 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 18:04:00.817 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 18:04:01.960 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus3_100nnn, num_processors = 20)
df8888 = result6785nn.dataframe
# Out:
# 2020-11-15 18:04:04.222 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 18:04:04.228 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 18:04:04.262 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 18:04:04.427 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-15 18:06:44.952 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 18:06:44.954 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 18:06:46.146 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100nnnn, num_processors = 12)
df9999 = result6785nn.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus2_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, df667.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.legend(['clus2x1'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 30)
    ax1.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# ax1.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus2_100)):
    ax2.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 30)
    ax2.set_ylim(ymin = 0, ymax = 1)
    ax2.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax2.legend(custom_lines, ['Clus2x2x3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, df888.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')  
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 30)
    ax3.set_ylim(ymin = 0, ymax = 1)
    ax3.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
    ax4.plot(tspan/60, df999.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 30)
    ax4.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus2x4', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of A20 pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df888.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100, num_processors = 20)
dfcyld1 = result6785nn.dataframe
# Out:
# 2020-11-04 14:14:04.923 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-04 14:14:04.928 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-04 14:14:04.963 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-04 14:14:05.127 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-04 14:17:00.205 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-04 14:17:00.206 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-04 14:17:01.514 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
tspan2 = np.linspace(0, 2880, 500)

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100n, num_processors = 10)
df3333 = result6785nn.dataframe
# Out:
# 2020-11-15 12:46:51.865 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:46:51.877 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:46:51.947 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:46:52.136 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 12:49:31.258 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:49:31.260 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:49:32.387 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nnnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnnn = solver6785nnnn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100nn, num_processors = 10)
df4444nn = result6785nnnn.dataframe
# Out:
# 2020-11-15 12:49:34.512 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:49:34.518 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:49:34.551 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:49:34.709 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 12:52:16.765 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:52:16.768 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:52:18.036 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan, df4444nn.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
# plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan, df4444n.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
# plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100nnn, num_processors = 10)
df5555 = result6785nn.dataframe
# Out:
# 2020-11-15 12:52:20.331 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-15 12:52:20.336 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-15 12:52:20.370 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-15 12:52:20.525 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-15 12:55:00.582 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-15 12:55:00.584 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-15 12:55:01.769 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus3_100nnnn, num_processors = 20)
df5566 = result6785nn.dataframe
# Out:
# 2020-11-04 14:11:16.903 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-04 14:11:16.909 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-04 14:11:16.944 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-04 14:11:17.108 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-04 14:14:01.411 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-04 14:14:01.412 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-04 14:14:02.566 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus2_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, df333.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.legend(['clus2x1'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 30)
    ax1.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# ax1.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus2_100)):
    ax2.plot(tspan/60, df444.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 30)
    ax2.set_ylim(ymin = 0, ymax = 1)
    ax2.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax2.legend(custom_lines, ['Clus2x2x3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, df555.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')  
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 30)
    ax3.set_ylim(ymin = 0, ymax = 1)
    ax3.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
    ax4.plot(tspan/60, df5566.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 30)
    ax4.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus2x4', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of A20 pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df444.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df555.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
dfa20ko = a20ko.dataframe

# %%
dfcyldko = cyldko.dataframe

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 's')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 0', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus0_5720_A20KO_wbindstr.pdf')
plt.show()

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.CYLD(brip=None, btraf = None):0}
                            ,param_values=clus1_100n[k], num_processors = 10)
df7 = result3528.dataframe

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus1_100nn[k], num_processors = 10)
df8 = result6785n.dataframe

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green', label = 'CYLDKO', zorder = 1, alpha = 1, marker = 's')
plt.plot(tspan/60, df7['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green', label = 'CYLDx10m', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df8['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'CYLDx100m',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'CYLDx1000',zorder = 1, alpha = 0.7, linestyle = '--')
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)

plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 1', fontsize=17)
plt.show()

# %%
solvercyld = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
resultcyld = solvercyld.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus1_100nn, num_processors = 10)
dfcyld = resultcyld.dataframe

# %%
solvercyld1 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
resultcyld1 = solvercyld1.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus1_100nnn, num_processors = 10)
dfcyld1 = resultcyld1.dataframe

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
    plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
    plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
#     plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
    plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
#     plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
    plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
threshold = 4000
threshold2 = 2500

# %%
df_threshtimesc2cyld = dfcyld.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
cluscyld1 = pd.DataFrame({'cyldko': df_threshtimesc2cylx2['MLKLa_obs']})

# %%
dfclus2c2 = pd.DataFrame(data = cluscyld1, columns = ['cyldko'])
dfclus2c2 = pd.melt(dfclus2c2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"cyldko": "green"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2, zorder=2, palette=my_pal)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.show()

# %%
threshold = 2772

# %%
df_threshtimesc2cylx3 = df5555.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
df_threshtimesc2cylx2nn = df4444nn.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
# df_threshtimesc2a20   = dfa201.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2a20x1 = df6677.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2a20x2 = df7777.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2a20x3 = df8888.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
# df_threshtimesc2a20x4 = df9999.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
df_threshtimesc2wt = df11.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
df_threshtimesc2cyld = dfcyld1.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2cyldx1= df3333.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2cyldx2 = df4444nn.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2cyldx3 = df5555.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
# df_threshtimesc2cylx4 = df5566.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
clusa20 = pd.DataFrame({'wt': df_threshtimesc2wt['MLKLa_obs'],
                            'a20ko': df_threshtimesc2a20['MLKLa_obs'], 
                          'a20kox1': df_threshtimesc2a20x1['MLKLa_obs'],
                       'a20kox2': df_threshtimesc2a20x2['MLKLa_obs'],
                       'a20kox3': df_threshtimesc2a20x3['MLKLa_obs']})

# %%
dfclus2a = pd.DataFrame(data = clusa20, columns = ['wt', 'a20ko', 'a20kox1', 'a20kox2','a20kox3'])
dfclus2a = pd.melt(dfclus2a)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": "indianred", "a20ko": "steelblue", "a20kox1": "steelblue", 
          "a20kox2": "steelblue", "a20kox3": "steelblue"}
b = sns.swarmplot(x="value", y="variable", data=dfclus2a, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 3 A20KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1800, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/Cluster3/pmlkl_100tnf_clus3_5720_A20KO_w24upratemod30hr_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": "indianred", "a20ko": "steelblue", "a20kox1": "steelblue", 
          "a20kox2": "steelblue", "a20kox3": "steelblue"}
b = sns.swarmplot(x="value", y="variable", data=dfclus2a, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 3 A20KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1800, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.savefig('figs/Cluster3/pmlkl_100tnf_clus3_5720_A20KO_w24upratemod30hr_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": "indianred", "a20ko": "steelblue", "a20kox1": "steelblue", 
          "a20kox2": "steelblue", "a20kox3": "steelblue"}
my_pal2 = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2nn":"mediumseagreen",
          "CYLDkox3":"mediumseagreen"}
b = sns.swarmplot(x="value", y="variable", data=dfclus2a, zorder=2, palette=my_pal, alpha = 0.6)
b2 = sns.swarmplot(x="value", y="variable", data=dfclus2c2nn, zorder=1, palette=my_pal2, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 A20 & CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_A20KO_w50dwnratemod48hr_swarm.pdf')
plt.show()

# %%
cluscyld2nn = pd.DataFrame({'wt': df_threshtimesc2wt['MLKLa_obs'],
                         'CYLDko': df_threshtimesc2cyld['MLKLa_obs'],
                         'CYLDkox1': df_threshtimesc2cyldx1['MLKLa_obs'], 
                          'CYLDkox2': df_threshtimesc2cyldx2['MLKLa_obs'],
                        'CYLDkox3': df_threshtimesc2cyldx3['MLKLa_obs']})

# %%
dfclus2c2nn = pd.DataFrame(data = cluscyld2nn, columns = ['wt', 'CYLDko','CYLDkox1', 'CYLDkox2','CYLDkox3'])
dfclus2c2nn = pd.melt(dfclus2c2nn)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2":"mediumseagreen",
          "CYLDkox3":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2nn, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 3 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 188, xmin = 0)
# x = [0, 200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800]
plt.xticks(np.arange(min(x), max(x)+.01, 200))
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.savefig('figs/Cluster3/pmlkl_100tnf_clus3_5720_CYLDKO_w28up30upratemod_swarm.pdf')
plt.show()

# %%
for i,l in enumerate(np.linspace(0,1800,500)):
    print(i,":",l)
# Out:
# 0 : 0.0
# 1 : 3.6072144288577155
# 2 : 7.214428857715431
# 3 : 10.821643286573146
# 4 : 14.428857715430862
# 5 : 18.03607214428858
# 6 : 21.64328657314629
# 7 : 25.250501002004007
# 8 : 28.857715430861724
# 9 : 32.46492985971944
# 10 : 36.07214428857716
# 11 : 39.67935871743487
# 12 : 43.28657314629258
# 13 : 46.8937875751503
# 14 : 50.501002004008015
# 15 : 54.10821643286573
# 16 : 57.71543086172345
# 17 : 61.322645290581164
# 18 : 64.92985971943888
# 19 : 68.5370741482966
# 20 : 72.14428857715431
# 21 : 75.75150300601203
# 22 : 79.35871743486975
# 23 : 82.96593186372746
# 24 : 86.57314629258516
# 25 : 90.18036072144288
# 26 : 93.7875751503006
# 27 : 97.39478957915831
# 28 : 101.00200400801603
# 29 : 104.60921843687375
# 30 : 108.21643286573146
# 31 : 111.82364729458918
# 32 : 115.4308617234469
# 33 : 119.03807615230461
# 34 : 122.64529058116233
# 35 : 126.25250501002004
# 36 : 129.85971943887776
# 37 : 133.46693386773546
# 38 : 137.0741482965932
# 39 : 140.6813627254509
# 40 : 144.28857715430863
# 41 : 147.89579158316633
# 42 : 151.50300601202406
# 43 : 155.11022044088176
# 44 : 158.7174348697395
# 45 : 162.3246492985972
# 46 : 165.93186372745492
# 47 : 169.53907815631263
# 48 : 173.14629258517033
# 49 : 176.75350701402806
# 50 : 180.36072144288576
# 51 : 183.9679358717435
# 52 : 187.5751503006012
# 53 : 191.18236472945893
# 54 : 194.78957915831663
# 55 : 198.39679358717436
# 56 : 202.00400801603206
# 57 : 205.6112224448898
# 58 : 209.2184368737475
# 59 : 212.82565130260522
# 60 : 216.43286573146293
# 61 : 220.04008016032066
# 62 : 223.64729458917836
# 63 : 227.2545090180361
# 64 : 230.8617234468938
# 65 : 234.4689378757515
# 66 : 238.07615230460922
# 67 : 241.68336673346693
# 68 : 245.29058116232466
# 69 : 248.89779559118236
# 70 : 252.5050100200401
# 71 : 256.1122244488978
# 72 : 259.7194388777555
# 73 : 263.32665330661325
# 74 : 266.9338677354709
# 75 : 270.54108216432866
# 76 : 274.1482965931864
# 77 : 277.7555110220441
# 78 : 281.3627254509018
# 79 : 284.9699398797595
# 80 : 288.57715430861725
# 81 : 292.1843687374749
# 82 : 295.79158316633266
# 83 : 299.3987975951904
# 84 : 303.0060120240481
# 85 : 306.6132264529058
# 86 : 310.2204408817635
# 87 : 313.82765531062125
# 88 : 317.434869739479
# 89 : 321.04208416833666
# 90 : 324.6492985971944
# 91 : 328.2565130260521
# 92 : 331.86372745490985
# 93 : 335.4709418837675
# 94 : 339.07815631262525
# 95 : 342.685370741483
# 96 : 346.29258517034066
# 97 : 349.8997995991984
# 98 : 353.5070140280561
# 99 : 357.11422845691385
# 100 : 360.7214428857715
# 101 : 364.32865731462925
# 102 : 367.935871743487
# 103 : 371.5430861723447
# 104 : 375.1503006012024
# 105 : 378.7575150300601
# 106 : 382.36472945891785
# 107 : 385.9719438877756
# 108 : 389.57915831663325
# 109 : 393.186372745491
# 110 : 396.7935871743487
# 111 : 400.40080160320645
# 112 : 404.0080160320641
# 113 : 407.61523046092185
# 114 : 411.2224448897796
# 115 : 414.82965931863725
# 116 : 418.436873747495
# 117 : 422.0440881763527
# 118 : 425.65130260521045
# 119 : 429.2585170340681
# 120 : 432.86573146292585
# 121 : 436.4729458917836
# 122 : 440.0801603206413
# 123 : 443.687374749499
# 124 : 447.2945891783567
# 125 : 450.90180360721445
# 126 : 454.5090180360722
# 127 : 458.11623246492985
# 128 : 461.7234468937876
# 129 : 465.3306613226453
# 130 : 468.937875751503
# 131 : 472.5450901803607
# 132 : 476.15230460921845
# 133 : 479.7595190380762
# 134 : 483.36673346693385
# 135 : 486.9739478957916
# 136 : 490.5811623246493
# 137 : 494.18837675350704
# 138 : 497.7955911823647
# 139 : 501.40280561122245
# 140 : 505.0100200400802
# 141 : 508.6172344689379
# 142 : 512.2244488977956
# 143 : 515.8316633266534
# 144 : 519.438877755511
# 145 : 523.0460921843687
# 146 : 526.6533066132265
# 147 : 530.2605210420842
# 148 : 533.8677354709419
# 149 : 537.4749498997996
# 150 : 541.0821643286573
# 151 : 544.689378757515
# 152 : 548.2965931863728
# 153 : 551.9038076152304
# 154 : 555.5110220440882
# 155 : 559.1182364729459
# 156 : 562.7254509018036
# 157 : 566.3326653306614
# 158 : 569.939879759519
# 159 : 573.5470941883767
# 160 : 577.1543086172345
# 161 : 580.7615230460922
# 162 : 584.3687374749499
# 163 : 587.9759519038076
# 164 : 591.5831663326653
# 165 : 595.1903807615231
# 166 : 598.7975951903808
# 167 : 602.4048096192384
# 168 : 606.0120240480962
# 169 : 609.6192384769539
# 170 : 613.2264529058116
# 171 : 616.8336673346694
# 172 : 620.440881763527
# 173 : 624.0480961923848
# 174 : 627.6553106212425
# 175 : 631.2625250501002
# 176 : 634.869739478958
# 177 : 638.4769539078156
# 178 : 642.0841683366733
# 179 : 645.6913827655311
# 180 : 649.2985971943888
# 181 : 652.9058116232464
# 182 : 656.5130260521042
# 183 : 660.1202404809619
# 184 : 663.7274549098197
# 185 : 667.3346693386774
# 186 : 670.941883767535
# 187 : 674.5490981963928
# 188 : 678.1563126252505
# 189 : 681.7635270541082
# 190 : 685.370741482966
# 191 : 688.9779559118236
# 192 : 692.5851703406813
# 193 : 696.1923847695391
# 194 : 699.7995991983968
# 195 : 703.4068136272546
# 196 : 707.0140280561122
# 197 : 710.6212424849699
# 198 : 714.2284569138277
# 199 : 717.8356713426854
# 200 : 721.442885771543
# 201 : 725.0501002004008
# 202 : 728.6573146292585
# 203 : 732.2645290581163
# 204 : 735.871743486974
# 205 : 739.4789579158316
# 206 : 743.0861723446894
# 207 : 746.6933867735471
# 208 : 750.3006012024048
# 209 : 753.9078156312626
# 210 : 757.5150300601202
# 211 : 761.1222444889779
# 212 : 764.7294589178357
# 213 : 768.3366733466934
# 214 : 771.9438877755512
# 215 : 775.5511022044088
# 216 : 779.1583166332665
# 217 : 782.7655310621243
# 218 : 786.372745490982
# 219 : 789.9799599198396
# 220 : 793.5871743486974
# 221 : 797.1943887775551
# 222 : 800.8016032064129
# 223 : 804.4088176352706
# 224 : 808.0160320641282
# 225 : 811.623246492986
# 226 : 815.2304609218437
# 227 : 818.8376753507014
# 228 : 822.4448897795592
# 229 : 826.0521042084168
# 230 : 829.6593186372745
# 231 : 833.2665330661323
# 232 : 836.87374749499
# 233 : 840.4809619238478
# 234 : 844.0881763527054
# 235 : 847.6953907815631
# 236 : 851.3026052104209
# 237 : 854.9098196392786
# 238 : 858.5170340681362
# 239 : 862.124248496994
# 240 : 865.7314629258517
# 241 : 869.3386773547094
# 242 : 872.9458917835672
# 243 : 876.5531062124248
# 244 : 880.1603206412826
# 245 : 883.7675350701403
# 246 : 887.374749498998
# 247 : 890.9819639278558
# 248 : 894.5891783567134
# 249 : 898.1963927855711
# 250 : 901.8036072144289
# 251 : 905.4108216432866
# 252 : 909.0180360721444
# 253 : 912.625250501002
# 254 : 916.2324649298597
# 255 : 919.8396793587175
# 256 : 923.4468937875752
# 257 : 927.0541082164328
# 258 : 930.6613226452906
# 259 : 934.2685370741483
# 260 : 937.875751503006
# 261 : 941.4829659318638
# 262 : 945.0901803607214
# 263 : 948.6973947895792
# 264 : 952.3046092184369
# 265 : 955.9118236472946
# 266 : 959.5190380761524
# 267 : 963.12625250501
# 268 : 966.7334669338677
# 269 : 970.3406813627255
# 270 : 973.9478957915832
# 271 : 977.555110220441
# 272 : 981.1623246492986
# 273 : 984.7695390781563
# 274 : 988.3767535070141
# 275 : 991.9839679358718
# 276 : 995.5911823647294
# 277 : 999.1983967935872
# 278 : 1002.8056112224449
# 279 : 1006.4128256513026
# 280 : 1010.0200400801604
# 281 : 1013.627254509018
# 282 : 1017.2344689378758
# 283 : 1020.8416833667335
# 284 : 1024.4488977955912
# 285 : 1028.056112224449
# 286 : 1031.6633266533067
# 287 : 1035.2705410821643
# 288 : 1038.877755511022
# 289 : 1042.4849699398799
# 290 : 1046.0921843687374
# 291 : 1049.6993987975952
# 292 : 1053.306613226453
# 293 : 1056.9138276553106
# 294 : 1060.5210420841684
# 295 : 1064.1282565130261
# 296 : 1067.7354709418837
# 297 : 1071.3426853707415
# 298 : 1074.9498997995993
# 299 : 1078.5571142284568
# 300 : 1082.1643286573146
# 301 : 1085.7715430861724
# 302 : 1089.37875751503
# 303 : 1092.9859719438878
# 304 : 1096.5931863727455
# 305 : 1100.200400801603
# 306 : 1103.807615230461
# 307 : 1107.4148296593187
# 308 : 1111.0220440881765
# 309 : 1114.629258517034
# 310 : 1118.2364729458918
# 311 : 1121.8436873747496
# 312 : 1125.4509018036072
# 313 : 1129.058116232465
# 314 : 1132.6653306613227
# 315 : 1136.2725450901803
# 316 : 1139.879759519038
# 317 : 1143.4869739478959
# 318 : 1147.0941883767534
# 319 : 1150.7014028056112
# 320 : 1154.308617234469
# 321 : 1157.9158316633266
# 322 : 1161.5230460921844
# 323 : 1165.1302605210421
# 324 : 1168.7374749498997
# 325 : 1172.3446893787575
# 326 : 1175.9519038076153
# 327 : 1179.559118236473
# 328 : 1183.1663326653306
# 329 : 1186.7735470941884
# 330 : 1190.3807615230462
# 331 : 1193.9879759519038
# 332 : 1197.5951903807616
# 333 : 1201.2024048096193
# 334 : 1204.809619238477
# 335 : 1208.4168336673347
# 336 : 1212.0240480961925
# 337 : 1215.63126252505
# 338 : 1219.2384769539078
# 339 : 1222.8456913827656
# 340 : 1226.4529058116232
# 341 : 1230.060120240481
# 342 : 1233.6673346693387
# 343 : 1237.2745490981963
# 344 : 1240.881763527054
# 345 : 1244.4889779559119
# 346 : 1248.0961923847697
# 347 : 1251.7034068136272
# 348 : 1255.310621242485
# 349 : 1258.9178356713428
# 350 : 1262.5250501002004
# 351 : 1266.1322645290581
# 352 : 1269.739478957916
# 353 : 1273.3466933867735
# 354 : 1276.9539078156313
# 355 : 1280.561122244489
# 356 : 1284.1683366733466
# 357 : 1287.7755511022044
# 358 : 1291.3827655310622
# 359 : 1294.9899799599198
# 360 : 1298.5971943887776
# 361 : 1302.2044088176353
# 362 : 1305.811623246493
# 363 : 1309.4188376753507
# 364 : 1313.0260521042085
# 365 : 1316.6332665330663
# 366 : 1320.2404809619238
# 367 : 1323.8476953907816
# 368 : 1327.4549098196394
# 369 : 1331.062124248497
# 370 : 1334.6693386773547
# 371 : 1338.2765531062125
# 372 : 1341.88376753507
# 373 : 1345.4909819639279
# 374 : 1349.0981963927857
# 375 : 1352.7054108216432
# 376 : 1356.312625250501
# 377 : 1359.9198396793588
# 378 : 1363.5270541082164
# 379 : 1367.1342685370741
# 380 : 1370.741482965932
# 381 : 1374.3486973947895
# 382 : 1377.9559118236473
# 383 : 1381.563126252505
# 384 : 1385.1703406813626
# 385 : 1388.7775551102204
# 386 : 1392.3847695390782
# 387 : 1395.991983967936
# 388 : 1399.5991983967936
# 389 : 1403.2064128256513
# 390 : 1406.8136272545091
# 391 : 1410.4208416833667
# 392 : 1414.0280561122245
# 393 : 1417.6352705410823
# 394 : 1421.2424849699398
# 395 : 1424.8496993987976
# 396 : 1428.4569138276554
# 397 : 1432.064128256513
# 398 : 1435.6713426853707
# 399 : 1439.2785571142285
# 400 : 1442.885771543086
# 401 : 1446.4929859719439
# 402 : 1450.1002004008017
# 403 : 1453.7074148296592
# 404 : 1457.314629258517
# 405 : 1460.9218436873748
# 406 : 1464.5290581162326
# 407 : 1468.1362725450902
# 408 : 1471.743486973948
# 409 : 1475.3507014028057
# 410 : 1478.9579158316633
# 411 : 1482.565130260521
# 412 : 1486.1723446893789
# 413 : 1489.7795591182364
# 414 : 1493.3867735470942
# 415 : 1496.993987975952
# 416 : 1500.6012024048096
# 417 : 1504.2084168336673
# 418 : 1507.8156312625251
# 419 : 1511.4228456913827
# 420 : 1515.0300601202405
# 421 : 1518.6372745490983
# 422 : 1522.2444889779558
# 423 : 1525.8517034068136
# 424 : 1529.4589178356714
# 425 : 1533.0661322645292
# 426 : 1536.6733466933867
# 427 : 1540.2805611222445
# 428 : 1543.8877755511023
# 429 : 1547.4949899799599
# 430 : 1551.1022044088177
# 431 : 1554.7094188376755
# 432 : 1558.316633266533
# 433 : 1561.9238476953908
# 434 : 1565.5310621242486
# 435 : 1569.1382765531062
# 436 : 1572.745490981964
# 437 : 1576.3527054108217
# 438 : 1579.9599198396793
# 439 : 1583.567134268537
# 440 : 1587.1743486973949
# 441 : 1590.7815631262524
# 442 : 1594.3887775551102
# 443 : 1597.995991983968
# 444 : 1601.6032064128258
# 445 : 1605.2104208416833
# 446 : 1608.8176352705411
# 447 : 1612.424849699399
# 448 : 1616.0320641282565
# 449 : 1619.6392785571143
# 450 : 1623.246492985972
# 451 : 1626.8537074148296
# 452 : 1630.4609218436874
# 453 : 1634.0681362725452
# 454 : 1637.6753507014027
# 455 : 1641.2825651302605
# 456 : 1644.8897795591183
# 457 : 1648.4969939879759
# 458 : 1652.1042084168337
# 459 : 1655.7114228456915
# 460 : 1659.318637274549
# 461 : 1662.9258517034068
# 462 : 1666.5330661322646
# 463 : 1670.1402805611224
# 464 : 1673.74749498998
# 465 : 1677.3547094188377
# 466 : 1680.9619238476955
# 467 : 1684.569138276553
# 468 : 1688.1763527054109
# 469 : 1691.7835671342687
# 470 : 1695.3907815631262
# 471 : 1698.997995991984
# 472 : 1702.6052104208418
# 473 : 1706.2124248496993
# 474 : 1709.8196392785571
# 475 : 1713.426853707415
# 476 : 1717.0340681362725
# 477 : 1720.6412825651303
# 478 : 1724.248496993988
# 479 : 1727.8557114228456
# 480 : 1731.4629258517034
# 481 : 1735.0701402805612
# 482 : 1738.6773547094188
# 483 : 1742.2845691382765
# 484 : 1745.8917835671343
# 485 : 1749.498997995992
# 486 : 1753.1062124248497
# 487 : 1756.7134268537075
# 488 : 1760.3206412825652
# 489 : 1763.9278557114228
# 490 : 1767.5350701402806
# 491 : 1771.1422845691384
# 492 : 1774.749498997996
# 493 : 1778.3567134268537
# 494 : 1781.9639278557115
# 495 : 1785.571142284569
# 496 : 1789.1783567134269
# 497 : 1792.7855711422847
# 498 : 1796.3927855711422
# 499 : 1800.0

# %%
print(len(clus3_100))
# Out:
# 2822

# %%
sim_idx_to_keep2 = [idx for idx in range(len(clus3_100)) if dfa201['MLKLa_obs'][idx].iloc[-111] > 2772]
print(len(sim_idx_to_keep2))
# Out:
# 2805

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2":"mediumseagreen",
          "CYLDkox3":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2nn, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 3 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/pmlkl_100tnf_clus3_5720_CYLDKO_w30upratemod30hrgrey_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2nn":"mediumseagreen",
          "CYLDkox3":"darkgrey"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2nn, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 3 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.savefig('figs/pmlkl_100tnf_clus3_5720_CYLDKO_w30upratemod30hrgrey_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2":"mediumseagreen",
          "CYLDkox3":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_wrip3ratemod_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2":"mediumseagreen",
          "CYLDkox3":"mediumseagreen", "CYLDkox4":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2800, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_wrip3ratemod_swarm.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
# plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KOx10', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df7['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue',  label = 'A20KOx100',zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df8['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'A20KOx1000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 0', fontsize=17)
plt.show()

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[21], num_processors = 10)
df2n = result6785n.dataframe

# %%
plt.figure()
plt.plot(tspan/60, df2n['MLKLa_obs'].iloc[:], lw=1.5, color ='blue', zorder = 1, alpha = 0.5)
plt.show()

# %%
solvercyld2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
cyldclus2 = solvercyld2.run(initials = { m.CYLD(brip=None, btraf = None):0},
                         param_values=clus2_100, num_processors = 20)

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
k = 2211

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(param_values=clus0_100[k], num_processors = 10)
df11 = result3528.dataframe

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[k], num_processors = 10)
df1n = result3528n.dataframe

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus0_100[k],
                              num_processors = 10)
df1nn = result3528n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df11['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
solver6785 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785 = solver6785.run(param_values=par_files[6785], num_processors = 10)
df2 = result6785.dataframe

# %%
solver5420 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420 = solver5420.run(param_values=par_files[5420], num_processors = 10)
df3 = result5420.dataframe

# %%
solver4230 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230 = solver4230.run(param_values=par_files[4230], num_processors = 10)
df4 = result4230.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
m = model100.components

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=par_files[6785], num_processors = 10)
df2n = result6785n.dataframe

# %%
solver5420n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420n = solver5420n.run(initials = {m.A20(brip = None):0},param_values=par_files[5420], num_processors = 10)
df3n = result5420n.dataframe

# %%
solver4230n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230n = solver4230n.run(initials = {m.A20(brip = None):0},param_values=par_files[4230], num_processors = 10)
df4n = result4230n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()
