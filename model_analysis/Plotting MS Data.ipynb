# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
# plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
mlkl0 = np.array([0.00963393,
0.047835596,
0.178040187,
0.286682676,
0.496675239,
0.546927983,
0.808172295,
0.768067163,
0.953283163,
1])
mlkl1 = np.array([
0.109455185,
0.079545498,
0.165191977,
0.234714162,
0.275383553,
0.33503123,
0.536180458,
0.952165104,
0.872486064,
1    
])
mlkl2= np.array([
0.053515904,
0.061801116,
0.32486143,
0.443036752,
0.334112285,
0.347380212,
0.529461751,
0.819135171,
0.835686282,
1    
])

time = np.array([0,
2,
4,
8,
10,
12,
14,
16,
18,
20])
stdev = np.array([0.05, 0.02, 0.08, 0.11, 0.11, 0.12, 0.16, 0.09, 0.06, 0.01])

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5])
y = np.power(x, 2) # Effectively y = x**2
e = np.array([1.5, 2.6, 3.7, 4.6, 5.5])

plt.errorbar(time, mlkl0, stdev, linestyle='None', fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(time, mlkl1, stdev, linestyle='None', fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(time, mlkl2, stdev, linestyle='None', fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
print(np.var(mlkl0))
print(np.var(mlkl1))
print(np.var(mlkl2))
# Out:
# 0.12176744589901509
# 0.06623335477336201
# 0.002075912295262599

# %%
## Create data
mlkl = [12897, 48247, 40843, 16122]
c8 = [5974, 22348, 18918, 7467]
rip3 = [5387, 20152, 17060, 6734]
tradd = [4657, 17421, 14748, 5821]
traf = [10886, 40723, 34473, 13608]
fadd = [2184, 8171, 6917, 2730]

## combine these different collections into a list    
data_to_plot = [mlkl, c8, rip3, tradd, traf, fadd]

# %%
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot)

## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = '#1b9e77' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5) 
ax.set_title('Label-Free MS: L929 Cells Treated With 10 ng/ml TNFa (1 hour)', size = 20)
ax.set_xticklabels(['MLKL', 'CASP8', 'RIP3', 'TRADD', 'TRAF', 'FADD'], size = 15)   
ax.set_xlabel('Proteins', size = 20)
ax.set_ylabel('Amount [molecules/cell]', size = 20)
ax.grid(b = None)
# Save the figure
ax.grid(False)
fig.savefig('ms_hr1_ct.png', bbox_inches='tight',dpi=400)

# %%
## Create data tr 23 hr 
mlkl = [3091, 9358, 8161, 4601]
c8 = [2118, 6412, 5851, 3152]
rip3 = [5939, 17983, 11997, 8841]
tradd = [2618, 7926, 6525, 3897]
traf = [6565, 19878, 15839, 9773]
fadd = [1733, 5248, 4333, 2580]
# mlkl = [3091, 9358, 7161, 4601]
# c8 = [2118, 2851, 3152]
# rip3 = [5939,  7997, 8841]
# tradd = [2618, 3525, 3897]
# traf = [6565, 8839, 9773]
# fadd = [1733,  2333, 2580]
data_to_plot = [mlkl, c8, rip3, tradd, traf, fadd]

# %%
# Create a figure instance
fig = plt.figure(2, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot)

## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(data_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = '#1b9e77' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5) 
ax.set_title('Label-Free MS: L929 Cells Treated With 10 ng/ml TNFa (control)', size = 20)
ax.set_xticklabels(['MLKL', 'Casp8', 'RIP3', 'TRADD', 'TRAF', 'FADD'], size = 15)   
ax.set_xlabel('Proteins', size = 20)
ax.set_ylabel('Amount [molecules/cell]', size = 20)
ax.grid(b = None)
ax.grid(False)
# Save the figure
fig.savefig('ms_hr1_ct.png', bbox_inches='tight',dpi=400)

# %%
## Create data tr 23 hr 
# mlkl0 = [3091, 9358, 8161, 4601]
# mlkl1 = [12897, 48247, 40843, 16122]
# mlkl2 = [11308, 13308, 11924, 16066]
mlkl = [3091, 9358, 7161, 4601]
c8 = [2118, 6412, 5851, 3152]
rip3 = [5939, 17983, 11997, 8841]
tradd = [2618, 7926, 6525, 3897]
traf = [6565, 19878, 15839, 9773]
fadd = [1733, 5248, 4333, 2580]

# c8 = [2118, 2851, 3152]
# rip3 = [5939,  7997, 8841]
# tradd = [2618, 3525, 3897]
# traf = [6565, 8839, 9773]
# fadd = [1733,  2333, 2580]
mlkl_to_plot = [mlkl, c8, rip3, tradd, traf, fadd]

# %%
# Create a figure instance
fig = plt.figure(2, figsize=(9, 6))

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(mlkl_to_plot)

## add patch_artist=True option to ax.boxplot() 
## to get fill color
bp = ax.boxplot(mlkl_to_plot, patch_artist=True)

## change outline color, fill color and linewidth of the boxes
for box in bp['boxes']:
    # change outline color
    box.set( color='#7570b3', linewidth=2)
    # change fill color
    box.set( facecolor = '#1b9e77' )

## change color and linewidth of the whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#7570b3', linewidth=2)

## change color and linewidth of the caps
for cap in bp['caps']:
    cap.set(color='#7570b3', linewidth=2)

## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#b2df8a', linewidth=2)

## change the style of fliers and their fill
for flier in bp['fliers']:
    flier.set(marker='o', color='#e7298a', alpha=0.5) 
ax.set_title('Label-Free MS: L929 Cells Treated With 10 ng/ml TNFa (24 hours)', size = 20)
ax.set_xticklabels(['MLKL', 'Casp8', 'RIP3', 'TRADD', 'TRAF', 'FADD'], size = 15)   
ax.set_xlabel('Proteins', size = 20)
ax.set_ylabel('Amount [molecules/cell]', size = 20)
ax.grid(b = None)
ax.grid(False)
# Save the figure
fig.savefig('ms_hr24_tr.png', bbox_inches='tight',dpi=400)
