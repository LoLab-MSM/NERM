# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
for i,pr in enumerate(model100.parameters):
    print(i,":",pr)

# %%
par_files = np.load('necro_pars10k_allclusmod.npy')
print(par_files.shape)

# %%
tspan = np.linspace(0, 1800, 500)
solver10 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result10 = solver10.run(initials = {m.TNF(brec=None):233}, param_values=par_files, num_processors = 10)
df10 = result10.dataframe

# %%
plt.figure()
for n in range(len(par_files)):
    plt.plot(tspan/60, df10.loc[n]['Flip_obs'].iloc[:]/3900, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
#     plt.set_xlim(xmin = 0, xmax = 24)
#     plt.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
plt.show()

# %%
clus0mod = clus0_100[:][:,14:]

# %%
idx = list(range(14, 54,1)) #index for parameter values after initial conditions 14-50
print(len(idx))
counter = 0
# samples_nonlog = 10 ** samples
ndims = len(idx)
plt.figure(figsize=(20, 20))
for i in range(1,41):
    plt.subplot(8, 5, i)
    # plt.plot(samples[:, counter])
#     sns.distplot(norm.rvs(size=n, loc=logps_vals[counter], scale=scaling[counter]), color='cyan')
    sns.distplot(clus0mod[:][:, counter])
    plt.title(model100.parameters[idx[counter]].name, fontdict={'fontsize': 10})
    counter += 1
    plt.xlabel("Log(10) Value", fontsize=10)
    plt.ylabel("Probability", fontsize=9, labelpad=15)
    plt.xlim(xmin = -1,xmax=10)
plt.subplots_adjust(wspace=0.5)
plt.subplots_adjust(hspace=0.6)
# plt.savefig('pydream_priorpost_traceplot_earm_gi.pdf', format='pdf', bbox_inches="tight")
plt.show()
# Out:
# 40

# %%
clus0_100 = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus0_100n = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus0_100nn = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus0_100nnn = np.load('necro_pars10k_cluster0_5720_mod.npy')
# clus1_100 = np.load('necro_pars10k_cluster1_5720_mod.npy')
# clus2_100 = np.load('necro_pars10k_cluster2_5720_mod.npy')
# clus3_100 = np.load('necro_pars10k_cluster3_5720_mod.npy')

# %%
print(clus0_100[:][:,48])

# %%
p = 46

# %%
clus0_100n[:][:,48]

# %%
clus0_100n[:][:,p] = clus0_100n[:][:,p]*10

# %%
clus0_100n[:][:,45]

# %%
clus0_100nn[:][:,p] = clus0_100nn[:][:,p]*100

# %%
clus0_100nn[:][:,45]

# %%
clus0_100nnn[:][:,p] = clus0_100nnn[:][:,p]*1000

# %%
clus0_100nnn[:][:,45]

# %%
clus0_100nn[:][:,48]

# %%
clus0_100nnn = np.load('necro_pars10k_cluster0_5720_mod.npy')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=True)
plt.subplot(131)
sns.distplot(clus0_100[:, 28])
# sns.distplot(clus0_100[:, 31])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, ['A20kf', 'CYLDkf'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)

plt.subplot(132)
sns.distplot(clus0_100[:, 29])
sns.distplot(clus0_100[:, 32])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, ['A20kr', 'CYLDkr'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(133)
sns.distplot(clus0_100[:, 30])
sns.distplot(clus0_100[:, 33])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, ['A20kcat', 'CYLDcat'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
# fig = plt.figure(figsize=(20, 15))
# for i in range(1,41):
#     ax = fig.add_subplot(8, 5, i)
    # plt.plot(samples[:, counter])
# fig = plt.figure(figsize=(20, 5))
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=True)
plt.subplot(131)
# sns.distplot(clus0_100[:, 42])
sns.distplot(clus0_100[:, 48])
# sns.distplot(clus0_100[:, 45])
# plt.ylim(ymax=0.3)
# plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4),
               Line2D([0], [0], color='red', lw=4)]
plt.legend(custom_lines, [r'$RIP1trunc$',r'$Necro$', 'c8rip3trunc'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)

plt.subplot(132)
sns.distplot(clus0_100[:, 40])
sns.distplot(clus0_100[:, 46])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, [r'$c8af$',r'$rip3f$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(133)
sns.distplot(clus0_100[:, 41])
sns.distplot(clus0_100[:, 47])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
x1001 = np.array([0, 30, 90, 270])
x1002 = np.array([480, 720, 960])
y1001 = np.array([0, 0.00885691708746097,0.0161886154261265,0.0373005242261882])
y1002 = np.array([0.2798939020159581, .7797294067, .98])

# %%
m = model100.components
tspan = np.linspace(0, 1800, 500)

# %%
k = 2211

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(param_values=clus0_100[k], num_processors = 10)
df1 = result3528.dataframe
# Out:
# 2020-11-11 14:47:37.663 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-11 14:47:37.674 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-11 14:47:37.744 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-11 14:47:37.835 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-11 14:47:38.120 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-11 14:47:38.122 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-11 14:47:38.197 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnn = solver6785nnn.run(initials = {m.A20(brip = None):0},param_values=clus0_100[k], num_processors = 20)
df2 = result6785nnn.dataframe
# Out:
# 2020-11-11 14:47:48.166 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-11 14:47:48.178 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-11 14:47:48.248 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-11 14:47:48.310 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-11 14:47:48.545 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-11 14:47:48.546 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-11 14:47:48.618 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus0_100n[k], num_processors = 10)
df3 = result6785n.dataframe
# Out:
# 2020-11-11 20:44:13.874 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-11 20:44:13.890 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-11 20:44:13.964 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-11 20:44:14.025 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-11 20:44:14.210 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-11 20:44:14.211 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-11 20:44:14.274 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus0_100nn[k], num_processors = 10)
df4 = result6785nn.dataframe
# Out:
# 2020-11-11 20:44:15.060 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-11 20:44:15.072 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-11 20:44:15.142 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-11 20:44:15.206 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-11 20:44:15.387 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-11 20:44:15.389 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-11 20:44:15.445 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnn = solver6785nnn.run(initials = {m.A20(brip = None):0},param_values=clus0_100nnn[k], num_processors = 20)
df5 = result6785nnn.dataframe
# Out:
# 2020-11-11 20:44:15.714 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-11 20:44:15.726 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-11 20:44:15.795 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-11 20:44:15.858 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-11 20:44:16.093 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-11 20:44:16.095 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-11 20:44:16.148 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 's')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 0', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus0_5720_A20KO_wbindstr.pdf')
plt.show()

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2) = plt.subplots(2,1, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus0_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, dfa20.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax1.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax1.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 24)
    ax1.set_ylim(ymin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='black', lw=4)]
    ax1.legend(custom_lines, ['Clus0_A20ko', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus0_100nnn)):
#     ax2.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label= '50% pMLKL')
    ax2.plot(tspan/60, dfa201.loc[n]['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    ax2.errorbar(x1001/60, y1001,
                 yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
                 (.07,.07,.07,.07)],
                       fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    ax2.errorbar(x1002/60, y1002,
                 yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 24)
    ax2.set_ylim(ymin = 0)
    ax2.grid(False)  
    custom_lines = [Line2D([0], [0], color='blue', lw=4),
                   Line2D([0], [0], color='black', lw=4)]
    ax2.legend(custom_lines, ['Clus0_A20kox1e3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

# fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
# fig.text(0.06, 0.5, 'Amount of A20 pMLKL under 100 ng/ml TNF(Normalized)',
#          ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
solver100a = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result100a = solver100a.run(initials = {m.A20(brip = None):0},param_values=clus0_100, num_processors = 20)
dfa20 = result100a.dataframe

# %%
solver100a1 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result100a1 = solver100a1.run(initials = {m.A20(brip = None):0},param_values=clus0_100nnn, num_processors = 20)
dfa201 = result100a1.dataframe

# %%
solver100a2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result100a2 = solver100a2.run(initials = {m.A20(brip = None):0},param_values=clus0_100nn, num_processors = 20)
dfa202 = result100a2.dataframe

# %%
threshold = 5000

# %%
# df_threshtimesc0100wt = c0df100wt.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc0a20   = dfa20.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc0a201 = dfa201.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
clusa20 = pd.DataFrame({'A20ko': df_threshtimesc0a20['MLKLa_obs'], 
                          'A20kox3': df_threshtimesc0a201['MLKLa_obs'],
                       'A20kox2': df_threshtimesc0a202['MLKLa_obs']})

# %%
dfclus0 = pd.DataFrame(data = clusa20, columns = ['A20ko', 'A20kox3', 'A20kox2'])
dfclus0 = pd.melt(dfclus0)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"A20ko": "blue", "A20kox2":"blue", "A20kox3":"blue"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus0, zorder=2, palette=my_pal)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 0",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1800, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
# plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KOx10', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df7['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue',  label = 'A20KOx100',zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df8['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'A20KOx1000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 0', fontsize=17)
plt.show()

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[21], num_processors = 10)
df2n = result6785n.dataframe

# %%
plt.figure()
plt.plot(tspan/60, df2n['MLKLa_obs'].iloc[:], lw=1.5, color ='blue', zorder = 1, alpha = 0.5)
plt.show()

# %%
solvercyld2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
cyldclus2 = solvercyld2.run(initials = { m.CYLD(brip=None, btraf = None):0},
                         param_values=clus2_100, num_processors = 20)

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
k = 2211

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus0_100[k],
                              num_processors = 10)
df1nn = result3528n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df11['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
solver6785 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785 = solver6785.run(param_values=par_files[6785], num_processors = 10)
df2 = result6785.dataframe

# %%
solver5420 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420 = solver5420.run(param_values=par_files[5420], num_processors = 10)
df3 = result5420.dataframe

# %%
solver4230 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230 = solver4230.run(param_values=par_files[4230], num_processors = 10)
df4 = result4230.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
m = model100.components

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=par_files[6785], num_processors = 10)
df2n = result6785n.dataframe

# %%
solver5420n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420n = solver5420n.run(initials = {m.A20(brip = None):0},param_values=par_files[5420], num_processors = 10)
df3n = result5420n.dataframe

# %%
solver4230n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230n = solver4230n.run(initials = {m.A20(brip = None):0},param_values=par_files[4230], num_processors = 10)
df4n = result4230n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()
