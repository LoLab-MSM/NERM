# %%
import sys 
# sys.path.append('/Users/geenaildefonso/Projects/NERM')
sys.path.append('../../')
sys.path.append('/home/ildefog/main/Projects/NERM/')
# print(sys.path)
from model_files.nerm_testing import model 
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns
os.environ["OPENBLAS_NUM_THREADS"] = "1"

# %%
c0 = np.load('sensitivity_analysis/NecroptosisSens/cluster0/necro_pars10k_cluster0_5720_mod.npy')
c1 = np.load('sensitivity_analysis/NecroptosisSens/cluster1/necro_pars10k_cluster1_5720_mod.npy')
c2 = np.load('sensitivity_analysis/NecroptosisSens/cluster2/necro_pars10k_cluster2_5720_mod.npy')
c3 = np.load('sensitivity_analysis/NecroptosisSens/cluster3/necro_pars10k_cluster3_5720_mod.npy')

# %%
c3extra = np.load('param_files/most_likely_par_10k_necropydream_may72020_667extra.npy')
print(c3extra[0])
# Out:
# [-8.24671854 -2.46804241 -4.33631828 -3.46433231  0.77565967 -1.65662398
#  -2.1093562   0.63865482 -4.83545384 -0.10465387 -1.38225581 -3.63423507
#  -0.86989605 -5.7682634  -5.21352304 -2.60755653 -2.65010736  1.91248764
#  -5.03937407  0.53656272  4.46678706 -1.84020948 -3.00427284 -5.68471312
#  -3.67370424 -1.63739967 -0.89974511  0.10134737 -3.2879064   0.19397849
#  -2.14056074 -3.37795975  0.88129403 -1.56411858 -2.5563091  -1.04850121
#  -4.37673012  0.3819979  -1.58478923  3.71995364]

# %%
np.save('params_testing/necro_pars10k_mode1_5720_mod.npy', c0)
np.save('params_testing/necro_pars10k_mode2_5720_mod.npy', c0)
np.save('params_testing/necro_pars10k_mode3_5720_mod.npy', c0)
np.save('params_testing/necro_pars10k_mode4_5720_mod.npy', c0)
np.save('params_testing/necro_pars10k_mode4w667_5720_mod.npy', c0)

# %%
for i,n in enumerate(tspan):
    print(i,":",n)
# Out:
# 0 : 0.0
# 1 : 3.6072144288577155
# 2 : 7.214428857715431
# 3 : 10.821643286573146
# 4 : 14.428857715430862
# 5 : 18.03607214428858
# 6 : 21.64328657314629
# 7 : 25.250501002004007
# 8 : 28.857715430861724
# 9 : 32.46492985971944
# 10 : 36.07214428857716
# 11 : 39.67935871743487
# 12 : 43.28657314629258
# 13 : 46.8937875751503
# 14 : 50.501002004008015
# 15 : 54.10821643286573
# 16 : 57.71543086172345
# 17 : 61.322645290581164
# 18 : 64.92985971943888
# 19 : 68.5370741482966
# 20 : 72.14428857715431
# 21 : 75.75150300601203
# 22 : 79.35871743486975
# 23 : 82.96593186372746
# 24 : 86.57314629258516
# 25 : 90.18036072144288
# 26 : 93.7875751503006
# 27 : 97.39478957915831
# 28 : 101.00200400801603
# 29 : 104.60921843687375
# 30 : 108.21643286573146
# 31 : 111.82364729458918
# 32 : 115.4308617234469
# 33 : 119.03807615230461
# 34 : 122.64529058116233
# 35 : 126.25250501002004
# 36 : 129.85971943887776
# 37 : 133.46693386773546
# 38 : 137.0741482965932
# 39 : 140.6813627254509
# ...

# %%
print(len(c0))
# Out:
# 3644

# %%
sim_idx_mode1 = [idx for idx in range(len(c0)) if m1alldf100wt['MLKLa_obs'][idx].iloc[305] >= 2772]
print(len(sim_idx_mode1))
# Out:
# 3604

# %%
c3all = np.concatenate([c3,all_pars])

# %%
n_pars = len(c3extra)
all_pars = np.zeros((n_pars, len(model.parameters)))

rate_params = model.parameters_rules()
param_values = np.array([p.value for p in model.parameters])
rate_mask = np.array([p in rate_params for p in model.parameters])

for i in range(n_pars):
    par = c3extra[i]
    param_values[rate_mask] = 10**par
    all_pars[i] = param_values

# %%
all_pars.shape
# Out:
# (667, 54)

# %%
print(len(c0))

# %%
list(model.initial_conditions)

# %%
mode4_100[0]

# %%
mode0 = np.load('param_files/necro_pars10k_cluster0_5720_modwo5.npy')
print(mode0[0])

# %%
mode1_100[0]

# %%
m1split1 = np.load('param_files/necro_pars10k_cluster11_5720_modsplit.npy')
m1split2 = np.load('param_files/necro_pars10k_cluster12_5720_modsplit.npy')
m1split3 = np.load('param_files/necro_pars10k_cluster13_5720_modsplit.npy')
print(len(m1split1))
print(len(m1split2))
print(len(m1split3))

# %%
mode1_100m = np.load('param_files/necro_pars10k_cluster0_5720_modwo5.npy')
mode2_100m = np.load('param_files/necro_pars10k_cluster1_5720_mod.npy')
mode3_100m = np.load('param_files/necro_pars10k_cluster2_5720_mod.npy')
mode4_100m = np.load('param_files/necro_pars10k_cluster3_5720_mod.npy')

# %%
mode1_100 = np.load('param_files/necro_pars10k_cluster1_5720_modwo5.npy')
mode2_100 = np.load('param_files/necro_pars10k_cluster2_5720_mod.npy')
mode3_100 = np.load('param_files/necro_pars10k_cluster3_5720_mod.npy')
# mode4_100e = np.load('../../param_files/most_likely_par_10k_necropydream_may72020_667extra.npy')
# mode4_100 = np.load('../../param_files/necro_pars10k_cluster4_5720_mod.npy')
mode4_100 = np.load('param_files/necro_pars10k_cluster4_5720_modw667.npy')
# pars = np.load('../../param_files/necro_pars10k_allclusmod.npy')

# %%
mode2 = np.load('param_files/necro_pars_mode2.npy')
print(len(mode2))
print(mode2[0])

# %%
print(len(mode1_100))
print(len(mode2_100))
print(len(mode3_100))
print(len(mode4_100))

# %%
tspan = np.linspace(0,1800,500)

# %%
solverm121 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
wtm121 = solverm121.run(param_values=c0, num_processors = 25)
m1alldf100wt = wtm121.dataframe
# Out:
# 2022-01-04 22:29:37.057 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-04 22:29:37.781 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-04 22:29:37.893 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-04 22:29:38.115 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-04 22:33:57.761 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-04 22:33:57.763 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-04 22:33:59.502 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
solverm122 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
wtm122 = solverm122.run(param_values=c1, num_processors = 25)
m2alldf100wt = wtm122.dataframe
# Out:
# 2022-01-04 22:34:02.441 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-04 22:34:02.446 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-04 22:34:02.480 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-04 22:34:02.584 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-04 22:35:00.411 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-04 22:35:00.411 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-04 22:35:01.092 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
solverm123 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
wtm123 = solverm123.run(param_values=c2, num_processors = 25)
m3alldf100wt = wtm123.dataframe
# Out:
# 2022-01-04 22:35:02.476 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-04 22:35:02.480 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-04 22:35:02.513 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-04 22:35:02.643 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-04 22:36:41.308 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-04 22:36:41.310 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-04 22:36:42.293 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
solverm124 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
wtm124 = solverm124.run(param_values=c3, num_processors = 25)
m4alldf100wt = wtm124.dataframe
# Out:
# 2022-01-04 22:36:43.992 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-04 22:36:43.997 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-04 22:36:44.031 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-04 22:36:44.196 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-04 22:39:35.477 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-04 22:39:35.478 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-04 22:39:36.923 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
solverm125 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
wtm125 = solverm125.run(param_values=c3all, num_processors = 25)
m45alldf100wt = wtm125.dataframe
# Out:
# 2022-01-05 14:59:21.950 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-05 14:59:21.962 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-05 14:59:22.042 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-05 14:59:22.283 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-05 15:03:25.271 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-05 15:03:25.273 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-05 15:03:27.096 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
thresh = 2772
ttd0 = []
for j in range(len(c0)):
#     print(f"this is output line {j}")
    i_range = range(len(m1alldf100wt.loc[j]['MLKLa_obs']))
    for i in i_range:
#         print(m3alldf100wt.loc[j]['MLKLa_obs'].iloc[i])
        if m1alldf100wt.loc[j]['MLKLa_obs'].iloc[i] > thresh:
            ttd0.append(m1alldf100wt.loc[j].index[i])
            break
        if i == i_range[-1]:
            ttd0.append(np.inf)
for i in range(len(ttd0)):
    if ttd0[i] == np.inf:
        ttd0[i] = 2100            
# print()        
# print(ttd0)
# print(len(ttd0))
# print('TTD = ', m3alldf100wt['time'][idx])

# %%
thresh = 2772
ttd1 = []
for j in range(len(c1)):
#     print(f"this is output line {j}")
    i_range = range(len(m2alldf100wt.loc[j]['MLKLa_obs']))
    for i in i_range:
#         print(m3alldf100wt.loc[j]['MLKLa_obs'].iloc[i])
        if m2alldf100wt.loc[j]['MLKLa_obs'].iloc[i] > thresh:
            ttd1.append(m2alldf100wt.loc[j].index[i])
            break
        if i == i_range[-1]:
            ttd1.append(np.inf)
for i in range(len(ttd1)):
    if ttd1[i] == np.inf:
        ttd1[i] = 2100            
# print()        
# print(ttd1)
# print(len(ttd1))
# print('TTD = ', m3alldf100wt['time'][idx])

# %%
thresh = 2772
ttd1 = []
for j in range(len(c2)):
#     print(f"this is output line {j}")
    i_range = range(len(m3alldf100wt.loc[j]['MLKLa_obs']))
    for i in i_range:
#         print(m3alldf100wt.loc[j]['MLKLa_obs'].iloc[i])
        if m3alldf100wt.loc[j]['MLKLa_obs'].iloc[i] > thresh:
            ttd1.append(m3alldf100wt.loc[j].index[i])
            break
        if i == i_range[-1]:
            ttd1.append(np.inf)
for i in range(len(ttd1)):
    if ttd1[i] == np.inf:
        ttd1[i] = 2100            
# print()        
# print(ttd1)
# print(len(ttd1))
# print('TTD = ', m3alldf100wt['time'][idx])

# %%
thresh = 2772
ttd3 = []
for j in range(len(c3)):
    i_range = range(len(m4alldf100wt.loc[j]['MLKLa_obs']))
    for i in i_range:
#         print(m3alldf100wt.loc[j]['MLKLa_obs'].iloc[i])
        if m4alldf100wt.loc[j]['MLKLa_obs'].iloc[i] > thresh:
            ttd3.append(m4alldf100wt.loc[j].index[i])
            break
        if i == i_range[-1]:
            ttd3.append(np.inf)
for i in range(len(ttd3)):
    if ttd3[i] == np.inf:
        ttd3[i] = 2100            
# print('TTD = ', m3alldf100wt['time'][idx])

# %%
threshold2 = 2772

# %%
df_threshtimesm1 = m1alldf100wt.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesm2   = m2alldf100wt.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesm3 = m3alldf100wt.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesm4   = m4alldf100wt.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
df_threshtimesm4b = m45alldf100wt.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
clus0n = pd.DataFrame({'WT1': df_threshtimesm1['MLKLa_obs'], 
                       'WT2': df_threshtimesm2['MLKLa_obs'],
                      'WT3': df_threshtimesm3['MLKLa_obs'], 
                       'WT4': df_threshtimesm4['MLKLa_obs']})
dfclus0n = pd.DataFrame(data = clus0n, columns = ['WT1', 'WT2','WT3', 'WT4'])
dfclus0n = pd.melt(dfclus0n)

# %%
clus2n = pd.DataFrame({'WT1': df_threshtimesm1['MLKLa_obs'], 
                       'WT2': df_threshtimesm2['MLKLa_obs'],
                      'WT3': df_threshtimesm3['MLKLa_obs'], 
                       'WT4': df_threshtimesm4['MLKLa_obs'],
                      'WT4b': df_threshtimesm4b['MLKLa_obs']})
dfclus2n = pd.DataFrame(data = clus2n, columns = ['WT1', 'WT2','WT3', 'WT4','WT4b'])
dfclus2n = pd.melt(dfclus2n)

# %%
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"WT1": "indianred", "WT2": "lightsalmon", "WT3": "mediumseagreen", "WT4":"cornflowerblue"}
# my_pal1 = {"wt0": "red", "a200":"blue"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus0n, zorder=2, palette=my_pal)
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
# b = sns.swarmplot(x="value", y="variable", data=dfclus0, zorder=2, palette=my_pal1)
b.set_xlabel("Time (m)",fontsize=15)
# b.set_ylabel("Mode 1 Degeneracy",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1800, xmin = 0)
# plt.savefig('figs/Cluster0/pmlkl_100tnf_clus0box_wswarm_5720_modnew.pdf')
plt.show()

# %%
import seaborn as sns
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"WT1": "indianred", "WT2": "lightsalmon", "WT3": "mediumseagreen", 
          "WT4":"cornflowerblue", "WT4b":"cornflowerblue"}
# my_pal1 = {"wt0": "red", "a200":"blue"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2n, zorder=2, palette=my_pal)
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
# b = sns.swarmplot(x="value", y="variable", data=dfclus0, zorder=2, palette=my_pal1)
b.set_xlabel("Time (m)",fontsize=15)
# b.set_ylabel("Mode 1 Degeneracy",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 1800, xmin = 0)
# plt.savefig('figs/Cluster0/pmlkl_100tnf_clus0box_wswarm_5720_modnew.pdf')
plt.show()

# %%
m = model.components

# %%
solverlubackdm1 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
lubackdm1 = solverlubackdm1.run(initials = {m.LUBAC(brip=None):726}, param_values=c2, num_processors = 25)
m1alldf100lubackd = lubackdm1.dataframe
# Out:
# 2022-01-04 22:48:18.833 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-04 22:48:18.845 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-04 22:48:18.915 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-04 22:48:19.070 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-04 22:49:53.781 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-04 22:49:53.783 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-04 22:49:54.771 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
solverlubacoem1 = ScipyOdeSimulator(model, tspan=tspan, verbose = True)
lubacoem1 = solverlubacoem1.run(initials = {m.LUBAC(brip=None):722600}, param_values=c2, num_processors = 25)
m1alldf100lubacoe = lubacoem1.dataframe
# Out:
# 2022-01-04 22:49:56.495 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Simulator created
# 2022-01-04 22:49:56.500 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Equation mode set to "cython"
# 2022-01-04 22:49:56.534 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] Simulation(s) started
# 2022-01-04 22:49:56.658 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] Multi-processor (parallel) mode using 25 processes
# 2022-01-04 22:51:28.389 - pysb.simulator.scipyode - INFO - [model_files.nerm_testing] All simulation(s) complete
# 2022-01-04 22:51:28.391 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor started
# 2022-01-04 22:51:29.407 - pysb.simulator.scipyode - DEBUG - [model_files.nerm_testing] SimulationResult constructor finished

# %%
df_threshtimesc2lubackd = m1alldf100lubackd.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2lubacoe = m1alldf100lubacoe.groupby('simulation').apply(lambda x: (x > threshold2).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
dfclus2n['species'] = 'test'

# %%
first_column = dfclus2n.pop('species')

# %%
dfclus2n.insert(0, 'Name', first_column)

# %%
sns.stripplot(data=dfclus2n, x="Name", y="value", hue="variable", dodge=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
df = sns.load_dataset('iris')
dfm = pd.melt(df, id_vars=["species"])
sns.stripplot(data=dfm, x="species", y="value", hue="variable", dodge=True)

# %%
#['lightcoral', 'lightseagreen', 'mediumpurple', 'peru']
mode2df = pd.DataFrame({'WT': df_threshtimesm1['MLKLa_obs']})
dfclus2 = pd.DataFrame(data = mode2df, columns = ['WT'])
dfclus2 = pd.melt(dfclus2)

# %%
#['lightcoral', 'lightseagreen', 'mediumpurple', 'peru']
mode2wt = pd.DataFrame({'WT': df_threshtimesm1['MLKLa_obs'],
                       'species':'wt'})
mode2lub = pd.DataFrame({'KD': df_threshtimesc2lubackd['MLKLa_obs'],
                          'OE': df_threshtimesc2lubacoe ['MLKLa_obs'],
                        'species': 'lubac2'})
mode2a20 = pd.DataFrame({'KD': df_threshtimesc2lubackd['MLKLa_obs'],
                          'OE': df_threshtimesc2lubacoe ['MLKLa_obs'],
                        'species': 'lubac3'})
mode2cyld = pd.DataFrame({'KD': df_threshtimesc2lubackd['MLKLa_obs'],
                          'OE': df_threshtimesc2lubacoe ['MLKLa_obs'],
                        'species': 'lubac4'})
framesm1 = [mode2wt,mode2dfn, mode2dfn2, mode2dfn3]
# framesm2 = [mode2wt,mode2dfn, mode2dfn2,mode2dfn3,mode2dfn4,mode2dfn5]
# framesm3 = [mode2wt,mode2dfn, mode2dfn2]
# framesm4 = [mode2wt,mode2dfn]
dfclus1 = pd.DataFrame(data = pd.concat(framesm1), columns = ['species','KD','WT','OE'])
# dfclus2 = pd.DataFrame(data = pd.concat(framesm2), columns = ['species','KD','WT','OE'])
# dfclus3 = pd.DataFrame(data = pd.concat(framesm3), columns = ['species','KD','WT','OE'])
# dfclus4 = pd.DataFrame(data = pd.concat(framesm4), columns = ['species','KD','WT','OE'])
# dfclus2nn = pd.melt(dfclus2nn)

# %%
dfm1 = pd.melt(dfclus1, id_vars=["species"])
dfm2 = pd.melt(dfclus2, id_vars=["species"])
dfm3 = pd.melt(dfclus3, id_vars=["species"])
dfm4 = pd.melt(dfclus4, id_vars=["species"])

# %%
plt.figure(figsize = (7,7))
sns.stripplot(data=dfm1, y="species", x="value", hue="variable", dodge=True, orient = 'h',linewidth=0.5,size=10)
plt.xlim(xmin = 1)
plt.legend(loc = 'lower right')

# %%
plt.figure(figsize = (15,15))
sns.stripplot(data=dfm2, y="species", x="value", hue="variable", dodge=True, orient = 'h',linewidth=0.5,size=5)
#               ,linewidth=0.3,size=15)
plt.xlim(xmin = 1)
plt.xticks(fontsize = 40)
plt.yticks(fontsize = 40)
plt.legend(loc = 'lower right')

# %%
plt.figure(figsize = (15,15))
sns.stripplot(data=dfm3, y="species", x="value", hue="variable", dodge=True, orient = 'h',linewidth=0.3,size=15)
plt.xlim(xmin = 1)
plt.xticks(fontsize = 40)
plt.yticks(fontsize = 40)
plt.legend(loc = 'lower right')

# %%
plt.figure(figsize = (7,7))
sns.stripplot(data=dfm4, y="species", x="value", hue="variable", dodge=True, 
              orient = 'h',linewidth=0.5,size=7)
plt.xlim(xmin = 1)
plt.legend(loc = 'lower right')

# %%
df = [mode2df, mode2dfn]

# %%
finaldf = pd.concat(df)

# %%
finaldf = pd.melt(finaldf)

# %%
finaldf.head()
# Out:
#   variable       value
# 0  LUBACKD  602.404810
# 1  LUBACKD  631.262525
# 2  LUBACKD  616.833667
# 3  LUBACKD  627.655311
# 4  LUBACKD  696.192385

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha':.5}, kde_kws={'linewidth':0.5})
# print('clus', np.mean(CI_k63))
# print('clus', np.std(CI_k63))
fig, ax = plt.subplots()
# sns.boxplot(x = 'variable', y = 'value', label ='WT',color=["red",'green'], bins=10, **kwargs, kde = True)
# g = sns.boxplot(y='variable',x='value',data=dfclus2n, showfliers=True, boxprops=dict(alpha=1))
g = sns.stripplot(y='variable',x='value',data=dfclus2nn, 
                        marker="o", alpha=0.3, order=['WT', 'LUBACKD','LUBACOE','WT2', 'LUBACKD2','LUBACOE2'])
# g = sns.stripplot(y='variable',x='value',data=dfclus2n, 
#                         marker="o", alpha=0.3, order=["WT", "LUBACKD", "LUBACOE"], color =['red', 'orange', 'blue'])
# g = sns.stripplot(y='variable',x='value',data=dfclus2n, 
#                         marker="o", alpha=0.3, order=["WT", "LUBACKD", "LUBACOE"], color =['red', 'orange', 'blue'])
# sns.distplot(mode2_lubacoe, label = 'LUBAC KD',color="blue", bins=10, **kwargs, kde = True)
# sns.distplot(mode2_lubackd, label = 'LUBAC OE',color="green", bins=10, **kwargs, kde = True)
# sns.distplot(CI_a20, label='uncluster',color="orange", bins=25, **kwargs)
# sns.distplot(CI_cyld, label='uncluster',color="deeppink", bins=25, **kwargs)
plt.xlabel('Time (m)')
plt.ylabel('Species')
plt.legend(loc = 'best')
plt.xlim(xmin = 1, xmax = 1000)
# ax.set_yticks([1, 1.5, 2])
# plt.ylim(ymax = 0.04)
# plt.xticks([0, 5, 10, 15, 20, 24])
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
plt.tight_layout()
# plt.savefig('mode2_lubackdoe_testingplots_strip.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha':.5}, kde_kws={'linewidth':0.5})
# print('clus', np.mean(CI_k63))
# print('clus', np.std(CI_k63))
fig, ax = plt.subplots()
# sns.boxplot(x = 'variable', y = 'value', label ='WT',color=["red",'green'], bins=10, **kwargs, kde = True)
# g = sns.boxplot(y='variable',x='value',data=dfclus2n, showfliers=True, boxprops=dict(alpha=1))
g = sns.stripplot(y='variable',x='value',data=dfclus2n, 
                        marker="o", alpha=0.3, order=["WT", "LUBACKD", "LUBACOE"])
# g = sns.stripplot(y='variable',x='value',data=dfclus2n, 
#                         marker="o", alpha=0.3, order=["WT", "LUBACKD", "LUBACOE"], color =['red', 'orange', 'blue'])
# g = sns.stripplot(y='variable',x='value',data=dfclus2n, 
#                         marker="o", alpha=0.3, order=["WT", "LUBACKD", "LUBACOE"], color =['red', 'orange', 'blue'])
# sns.distplot(mode2_lubacoe, label = 'LUBAC KD',color="blue", bins=10, **kwargs, kde = True)
# sns.distplot(mode2_lubackd, label = 'LUBAC OE',color="green", bins=10, **kwargs, kde = True)
# sns.distplot(CI_a20, label='uncluster',color="orange", bins=25, **kwargs)
# sns.distplot(CI_cyld, label='uncluster',color="deeppink", bins=25, **kwargs)
plt.xlabel('Time (m)')
plt.ylabel('Species')
plt.legend(loc = 'best')
plt.xlim(xmin = 1, xmax = 1000)
ax.set_yticks([1, 1.5, 2])
# plt.ylim(ymax = 0.04)
# plt.xticks([0, 5, 10, 15, 20, 24])
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
plt.tight_layout()
# plt.savefig('mode2_lubackdoe_testingplots_strip.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha':.5}, kde_kws={'linewidth':2})
# print('clus', np.mean(CI_k63))
# print('clus', np.std(CI_k63))
fig, ax = plt.subplots()
# sns.boxplot(x = 'variable', y = 'value', label ='WT',color=["red",'green'], bins=10, **kwargs, kde = True)
# g = sns.boxplot(y='variable',x='value',data=dfclus2n, showfliers=True, boxprops=dict(alpha=1))
g = sns.violinplot(y='variable',x='value',data=dfclus2n, 
                        marker="o", alpha=0.3, order=["WT", "LUBACKD", "LUBACOE"])
# sns.distplot(mode2_lubacoe, label = 'LUBAC KD',color="blue", bins=10, **kwargs, kde = True)
# sns.distplot(mode2_lubackd, label = 'LUBAC OE',color="green", bins=10, **kwargs, kde = True)
# sns.distplot(CI_a20, label='uncluster',color="orange", bins=25, **kwargs)
# sns.distplot(CI_cyld, label='uncluster',color="deeppink", bins=25, **kwargs)
plt.xlabel('Time (h)')
plt.ylabel('Frequency')
plt.legend(loc = 'best')
# plt.xlim(xmin = 400, xmax = 1000)
# plt.ylim(ymax = 0.04)
# plt.xticks([0, 5, 10, 15, 20, 24])
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
# plt.savefig('k63_necrosome_pmlkl.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
# my_pal = {"WT": "mediumaquamarine", "CYLDKO": "limegreen", "A20KO":"darkgreen"}
my_pal = {"WT": "cornflowerblue", "LUBACKD": "blue", "LUBACOE":"darkblue"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2n, zorder=2, palette=my_pal)
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b.set_xlabel("Time (m)",fontsize=20)
plt.xticks(fontsize = 20)
# b.set_ylabel("Cluster 0 New",fontsize=15)
b.tick_params(labelsize=20)
plt.xlim(xmax = 1800, xmin = 0)
# plt.savefig('pmlkl_cyldkoa20ko_100tnf_mode4was2_swarm_bluecolors.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (10,5))
# my_pal = {"WT": "mediumaquamarine", "CYLDKO": "limegreen", "A20KO":"darkgreen"}
my_pal = {"WT": "blue", "LUBACKD": 'darkorange', "LUBACOE":"green"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2n, zorder=2, palette=my_pal)
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b.set_xlabel("Time (m)",fontsize=20)
plt.xticks(fontsize = 20)
# b.set_ylabel("Cluster 0 New",fontsize=15)
b.tick_params(labelsize=20)
plt.xlim(xmax = 1800, xmin = 0)
plt.tight_layout()
plt.savefig('mode2_lubackdoe_testingplots_swarm.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (6, 4))
for n in range(len(c2)):
    plt.plot(tspan, m3alldf100wt.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, 
             zorder = 1, color = 'blue', alpha= 0.4)
    plt.plot(tspan, m1alldf100lubackd.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, 
             zorder = 1, color = 'orange', alpha = 0.25)
    plt.plot(tspan, m1alldf100lubacoe.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, 
             zorder = 1, color = 'green', alpha = 0.25)
# colormap = plt.cm.Reds #nipy_spectral, Set1,Paired   
# colors = [colormap(i) for i in np.linspace(0, 1,len(ax.lines))]
# for i,j in enumerate(ax.lines):
#     j.set_color(colors[i])
# ax1.legend(loc=2)    
plt.xlabel("Time (m)", fontsize=15)
plt.ylabel("[pMLKL] Normalized", fontsize=15)
plt.xlim(xmin = 0, xmax = 1800)
plt.ylim(ymin = 0)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
ax.grid(False)
# ax.set_xticks([0, 5, 10, 15, 20, 24])
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4),
               Line2D([0], [0], color='green', lw=4)]
plt.legend(custom_lines, ['WT', 'LUBACKD', 'LUBACOE'], prop={'size': 10}, loc = 'best')
plt.tight_layout()
plt.savefig('mode2_lubackdoe_testingplots_linesmin.pdf')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (3,3))
for n in range(len(c2)):
    plt.plot(tspan/60, m3alldf100wt.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, 
             zorder = 1, color = 'red', alpha= 0.4)
    plt.plot(tspan/60, m1alldf100lubackd.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, 
             zorder = 1, color = 'cornflowerblue', alpha = 0.25)
    plt.plot(tspan/60, m1alldf100lubacoe.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, 
             zorder = 1, color = 'green', alpha = 0.25)
# colormap = plt.cm.Reds #nipy_spectral, Set1,Paired   
# colors = [colormap(i) for i in np.linspace(0, 1,len(ax.lines))]
# for i,j in enumerate(ax.lines):
#     j.set_color(colors[i])
# ax1.legend(loc=2)    
plt.xlabel("Time (h)", fontsize=20)
plt.ylabel("[pMLKL] Normalized", fontsize=20)
plt.xlim(xmin = 0, xmax = 16)
plt.ylim(ymin = 0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
ax.grid(False)
ax.set_xticks([0, 5, 10, 15, 20, 24])
custom_lines = [Line2D([0], [0], color='red', lw=4),
                Line2D([0], [0], color='cornflowerblue', lw=4),
               Line2D([0], [0], color='green', lw=4)]
plt.legend(custom_lines, ['WT', 'LUBACKD', 'LUBACOE'], prop={'size': 10}, loc = 'best')
plt.tight_layout()
# plt.savefig('mode4_pmlkl_allpars_bluecolor_nogrid.pdf')
plt.show()

# %%
c2 = []
clus_idxs = np.array(range(wtm123.nsims))
for idx in clus_idxs: 
    mlkl_traj = wtm123.observables[idx]['MLKLa_obs']
    ysim_mlkl_norm = mlkl_traj / np.nanmax(mlkl_traj)
    st, sc, sk = scipy.interpolate.splrep(tspan, ysim_mlkl_norm)
    try:
        t10 = scipy.interpolate.sproot((st, sc - 0.10, sk))[0]
        t90 = scipy.interpolate.sproot((st, sc - 0.90, sk))[0]
    except IndexError:
        t10 = 0
        t90 = 0

    # time of death  = halfway point between 10 and 90%
    td = (t10 + t90) / 2
    c2.append(td)

# %%
mode2_lubacoe = []
clus_idxs = np.array(range(lubackdm1.nsims))
for idx in clus_idxs: 
    mlkl_traj = lubackdm1.observables[idx]['MLKLa_obs']
    ysim_mlkl_norm = mlkl_traj / np.nanmax(mlkl_traj)
    st, sc, sk = scipy.interpolate.splrep(tspan, ysim_mlkl_norm)
    try:
        t10 = scipy.interpolate.sproot((st, sc - 0.10, sk))[0]
        t90 = scipy.interpolate.sproot((st, sc - 0.90, sk))[0]
    except IndexError:
        t10 = 0
        t90 = 0

    # time of death  = halfway point between 10 and 90%
    td = (t10 + t90) / 2
    mode2_lubacoe.append(td)

# %%
mode2_lubackd = []
clus_idxs = np.array(range(lubacoem1.nsims))
for idx in clus_idxs: 
    mlkl_traj = lubacoem1.observables[idx]['MLKLa_obs']
    ysim_mlkl_norm = mlkl_traj / np.nanmax(mlkl_traj)
    st, sc, sk = scipy.interpolate.splrep(tspan, ysim_mlkl_norm)
    try:
        t10 = scipy.interpolate.sproot((st, sc - 0.10, sk))[0]
        t90 = scipy.interpolate.sproot((st, sc - 0.90, sk))[0]
    except IndexError:
        t10 = 0
        t90 = 0

    # time of death  = halfway point between 10 and 90%
    td = (t10 + t90) / 2
    mode2_lubackd.append(td)

# %%
from sklearn.datasets import load_iris
import seaborn as sns

iris = load_iris()
iris = pd.DataFrame(data=np.c_[iris['data'], iris['target']],
                    columns=iris['feature_names'] + ['target'])

sns.distplot(data=iris, x='sepal length (cm)', hue='target', kind='kde', fill=True, 
            palette=sns.color_palette('bright')[:3], height=5, aspect=1.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-f7521b1b494d> in <module>
#       7
#       8 sns.distplot(data=iris, x='sepal length (cm)', hue='target', kind='kde', fill=True,
# ----> 9             palette=sns.color_palette('bright')[:3], height=5, aspect=1.5)
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
df4 = wtm123.dataframe[['__s36']]
df2 = m1alldf100lubackd[['__s36']]
df3 = m1alldf100lubacoe[['__s36']]

# %%
df1['LubacOE'] = df3['__s36']
df1['pMLKL'] = df1['__s36']
df1['LubacKD'] = df2['__s36']

# %%
# df1 = df1.drop(columns=['__s36'])
print(df1.head())
# Out:
#                            LubacOE         pMLKL       LubacKD
# simulation time
# 0          0.000000   0.000000e+00  0.000000e+00  0.000000e+00
#            3.607214   2.817197e-11  2.769511e-11  2.397239e-11
#            7.214429   3.363080e-09  3.334208e-09  3.099497e-09
#            10.821643  5.353036e-08  5.323621e-08  5.070830e-08
#            14.428858  3.744847e-07  3.729578e-07  3.596336e-07

# %%
plt.bar(x = [df4, df2, df3], height = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-2f44351e0a86> in <module>
# ----> 1 plt.bar(x = [df4, df2, df3], height = 1)
#
# /home/jupyterhub/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2455     return gca().bar(
#    2456         x, height, width=width, bottom=bottom, align=align,
# -> 2457         **({"data": data} if data is not None else {}), **kwargs)
#    2458
#    2459
#
# /home/jupyterhub/miniconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.figure()
sns.pairplot(df1, height=2.5)
# g = sns.PairGrid(df)
# g.map_upper(sns.scatterplot,color='red')
# g.map_lower(sns.scatterplot, color='green')
# g.map_diag(plt.hist)
plt.show()

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha':.5}, kde_kws={'linewidth':2})
# print('clus', np.mean(CI_k63))
# print('clus', np.std(CI_k63))
fig, ax = plt.subplots()
sns.distplot(np.log10(c2), label ='WT',color="red", bins=100, **kwargs, kde = False)
sns.distplot(np.log10(mode2_lubacoe), label = 'LUBAC KD',color="blue", bins=100, **kwargs, kde = False)
sns.distplot(np.log10(mode2_lubackd), label = 'LUBAC OE',color="green", bins=100, **kwargs, kde = False)
# sns.distplot(CI_a20, label='uncluster',color="orange", bins=25, **kwargs)
# sns.distplot(CI_cyld, label='uncluster',color="deeppink", bins=25, **kwargs)
plt.xlabel('Time (h)')
plt.ylabel('Frequency')
plt.legend(loc = 'best')
plt.xlim(xmin = 400, xmax = 1000)
# plt.ylim(ymax = 0.04)
# plt.xticks([0, 5, 10, 15, 20, 24])
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
# plt.savefig('k63_necrosome_pmlkl.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-365-09a976014589> in <module>
#       4 # print('clus', np.std(CI_k63))
#       5 fig, ax = plt.subplots()
# ----> 6 sns.distplot(np.log10(c2), label ='WT',color="red", bins=100, **kwargs, kde = False)
#       7 sns.distplot(np.log10(mode2_lubacoe), label = 'LUBAC KD',color="blue", bins=100, **kwargs, kde = False)
#       8 sns.distplot(np.log10(mode2_lubackd), label = 'LUBAC OE',color="green", bins=100, **kwargs, kde = False)
#
# /home/jupyterhub/miniconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     223         hist_color = hist_kws.pop("color", color)
#     224         ax.hist(a, bins, orientation=orientation,
# --> 225                 color=hist_color, **hist_kws)
# ...

# %%
df = sns.load_dataset('penguins')
sns.boxplot(x=df["species"], y=df["bill_length_mm"])

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha':.5}, kde_kws={'linewidth':2})
# print('clus', np.mean(CI_k63))
# print('clus', np.std(CI_k63))
fig, ax = plt.subplots()
sns.kdeplot(c2, label ='WT',color="red", bins=1000, hist = False, **kwargs, kde = True)
sns.kdeplot(mode2_lubacoe, label = 'LUBAC KD',color="blue", bins=1000,hist =  False, **kwargs, kde = True)
sns.kdeplot(mode2_lubackd, label = 'LUBAC OE',color="green", bins=1000, hist =  False,**kwargs, kde = True)
# sns.distplot(CI_a20, label='uncluster',color="orange", bins=25, **kwargs)
# sns.distplot(CI_cyld, label='uncluster',color="deeppink", bins=25, **kwargs)
plt.xlabel('Time (h)')
plt.ylabel('Frequency')
plt.legend(loc = 'best')
plt.xlim(xmin = 500, xmax = 700)
# plt.ylim(ymax = 0.04)
# plt.xticks([0, 5, 10, 15, 20, 24])
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
# plt.savefig('k63_necrosome_pmlkl.pdf')
plt.show()

# %%
print(sns.__version__)
# Out:
# 0.9.0

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha':.5}, kde_kws={'linewidth':2, 'bw':1})
# print('clus', np.mean(CI_k63))
# print('clus', np.std(CI_k63))
fig, ax = plt.subplots()
sns.distplot(c2, label ='WT',color="red", bins=1000, hist = False,kde = True, **kwargs)
sns.distplot(mode2_lubacoe, label = 'LUBAC KD',color="blue", bins=1000,hist =  False,kde = True, **kwargs)
sns.distplot(mode2_lubackd, label = 'LUBAC OE',color="green", bins=1000, hist =  False,**kwargs, kde = True)
# sns.distplot(CI_a20, label='uncluster',color="orange", bins=25, **kwargs)
# sns.distplot(CI_cyld, label='uncluster',color="deeppink", bins=25, **kwargs)
plt.xlabel('Time (h)')
plt.ylabel('Frequency')
plt.legend(loc = 'best')
plt.xlim(xmin = 500, xmax = 700)
# plt.ylim(ymax = 0.04)
# plt.xticks([0, 5, 10, 15, 20, 24])
right_side = ax.spines["right"]
right_side.set_visible(False)
top = ax.spines["top"]
top.set_visible(False)
# plt.savefig('k63_necrosome_pmlkl.pdf')
plt.show()

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

# %%
data.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
mode2dfn5 = pd.DataFrame({'KD': df_threshtimesc2lubackd['MLKLa_obs'],
                          'OE': df_threshtimesc2lubacoe ['MLKLa_obs']})

# %%
mode2dfn5.columns
# Out:
# Index(['KD', 'OE'], dtype='object')

# %%
mode2wt = pd.DataFrame({'WT': df_threshtimesm1['MLKLa_obs']})

# %%
sns.kdeplot(
   data=mode2dfn5,
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)

# %%
sns.distplot(mode2dfn5['KD'], label='KD', bins = 100, kde = False)
sns.distplot(mode2dfn5['OE'], label='OE', bins = 100, kde = False)
sns.distplot(mode2wt['WT'], label='WT', bins = 100, kde = False)
plt.xlim(xmin = 300, xmax = 1000)
plt.xlabel('split_frac');

# %%
sns.kdeplot(mode2dfn5['KD'], label='KD', shade=True, bw = 20)
sns.kdeplot(mode2dfn5['OE'], label='OE', shade=True, bw = 20)
sns.kdeplot(mode2wt['WT'], label='WT', shade=True, bw = 20)
plt.xlim(xmin = 300, xmax = 1000)
plt.xlabel('split_frac');

# %%
sns.jointplot("KD", "OE", data=mode2dfn5, kind='reg');

# %%
with sns.axes_style('white'):
    sns.jointplot('KD', 'OE', mode2dfn5, kind='hex');

# %%
for col in 'KD':
    sns.kdeplot(mode2dfn[col], shade=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/jupyterhub/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'K'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-385-3f70b687cb22> in <module>
#       1 for col in 'KD':
# ...

# %%
# Assign colors for each airline and the names
colors = ['blue', 'green', 'orange']
names = ['Mode2', 'LubacOE', 'LUBACKD']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([c2, mode2_lubacoe,mode2_lubackd], bins=10, range=None, normed=None, weights=None, density=True)

# Plot formatting
plt.legend()
plt.xlabel('Time (m)')
plt.ylabel('Frequency')
plt.xlim(xmin = 400, xmax = 800)
plt.tight_layout()
# plt.savefig('mode2_lubackdoe_testingplots_hist.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Assign colors for each airline and the names
colors1 = ['red']
names1 = ['Mode2']
colors2 = ['blue']
names2 = ['LUBACOE']
colors3 = ['green']
names3 = ['LUBACKD']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([c2], stacked=True, bins = 50,normed=False,
         color = colors1, label=names1)
plt.hist([mode2_lubacoe], stacked=True, bins = 50,normed=False,
         color = colors2, label=names2, alpha= 0.5)
plt.hist([mode2_lubackd], stacked=True, bins = 50,normed=False,
         color = colors3, label=names3, alpha= 0.5)

# Plot formatting
plt.legend()
plt.xlabel('Time (m)')
plt.ylabel('Frequency')
plt.xlim(xmin = 400, xmax = 1000)
plt.show()
# Out:
#   File "<ipython-input-135-863423bdd6c6>", line 12
#     color = colors1, label=names1, stacked = True)
#                                   ^
# SyntaxError: keyword argument repeated

# %%
# Assign colors for each airline and the names
colors = ['blue']
names = ['Mode2']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([c2], stacked=True, bins = 100,normed=False,
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Time (m)')
plt.ylabel('Frequency')
plt.xlim(xmin = 300, xmax = 900)
plt.tight_layout()
plt.savefig('mode2_wt_testingplots_histsolo.pdf')
plt.show()

# %%
# Assign colors for each airline and the names
colors = ['green']
names = ['LubacOE']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([mode2_lubacoe,], stacked=True, bins = 100,normed=False,
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Time (m)')
plt.ylabel('Frequency')
plt.xlim(xmin = 300, xmax = 900)
plt.tight_layout()
plt.savefig('mode2_lubacoe_testingplots_histsolo.pdf')
plt.show()

# %%
# Assign colors for each airline and the names
colors = ['orange']
names = ['LUBACKD']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([mode2_lubackd], stacked=True, bins = 100,normed=False,
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Time (m)')
plt.ylabel('Frequency')
plt.xlim(xmin = 300, xmax = 900)
plt.tight_layout()
plt.savefig('mode2_lubackd_testingplots_histsolo.pdf')
plt.show()

# %%
# Assign colors for each airline and the names
colors = ['green', 'red', 'blue']
names = ['Mode2', 'LubacOE', 'LUBACKD']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([c2, mode2_lubacoe,mode2_lubackd], stacked=False, bins = 50,normed=False,
         color = colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Time (m)')
plt.ylabel('Frequency')
plt.xlim(xmin = 400, xmax = 800)
plt.grid(False)
plt.show()
