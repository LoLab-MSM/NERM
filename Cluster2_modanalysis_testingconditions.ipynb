# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
for i,pr in enumerate(model100.parameters):
    print(i,":",pr)

# %%
par_files = np.load('necro_pars10k_allclusmod.npy')

# %%
clus2_100 = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus2_100n = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus2_100nn = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus2_100nnn = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus2_100nnnn = np.load('necro_pars10k_cluster2_5720_mod.npy')

# %%
clus2_100nn = np.load('necro_pars10k_cluster2_5720_mod.npy')

# %%
g = 47

# %%
a = 43

# %%
p = 53

# %%
z = 45

# %%
clus2_100n[:][:,g] = clus2_100n[:][:,g]*10

# %%
clus2_100nn[:][:,g] = clus2_100nn[:][:,g]*100

# %%
clus2_100nnn[:][:,g] = clus2_100nnn[:][:,g]*1000

# %%
clus2_100nnnn[:][:,g] = clus2_100nnnn[:][:,g]*10000

# %%
clus2_100n[:][:,a] = clus2_100n[:][:,a]*10

# %%
clus2_100nn[:][:,a] = clus2_100nn[:][:,a]*100

# %%
clus2_100nnn[:][:,a] = clus2_100nnn[:][:,a]*1000

# %%
clus2_100nnnn[:][:,a] = clus2_100nnnn[:][:,a]*10000

# %%
print(clus2_100n[:][:,p])
print(clus2_100n[:][:,p]/10)
print(clus2_100n[:][:,p]/100)
print(clus2_100n[:][:,p]/1000)

# %%
clus2_100n[:][:,p] = clus2_100n[:][:,p]/10

# %%
clus2_100nn[:][:,p] = clus2_100nn[:][:,p]/100

# %%
clus2_100nnn[:][:,p] = clus2_100nnn[:][:,p]/1000

# %%
clus2_100nnnn[:][:,p] = clus2_100nnnn[:][:,p]/10000

# %%
clus2_100n[:][:,z] = clus2_100n[:][:,z]*10

# %%
clus2_100nn[:][:,z] = clus2_100nn[:][:,z]*100

# %%
clus2_100nnn[:][:,z] = clus2_100nnn[:][:,z]*1000

# %%
clus2_100nnnn[:][:,z] = clus2_100nnnn[:][:,z]*10000

# %%
# fig = plt.figure(figsize=(20, 15))
# for i in range(1,41):
#     ax = fig.add_subplot(8, 5, i)
    # plt.plot(samples[:, counter])
# fig = plt.figure(figsize=(20, 5))
fig, axes = plt.subplots(1, 4, figsize=(28, 7), sharex=True)
plt.subplot(141)
# sns.distplot(clus2_100[:, 42])
sns.distplot(clus2_100[:, 51])
# sns.distplot(clus2_100[:, 48])
# sns.distplot(clus2_100n[:, 45])
# sns.distplot(clus2_100nn[:, 45])
# plt.ylim(ymax=2)
plt.xlim(xmin = -1,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4),
               Line2D([0], [0], color='red', lw=4)]
# plt.legend(custom_lines, [r'$RIP1trunc$',r'$Necro$', 'c8rip3trunc'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)

plt.subplot(142)
sns.distplot(clus2_100[:, 52])
# sns.distplot(clus2_100[:, 51])
# plt.ylim(ymax=10)
plt.xlim(xmin = -0.5,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8af$',r'$rip3f$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(143)
# sns.distplot(clus2_100[:, 41])
sns.distplot(clus2_100[:, 53])
# sns.distplot(clus2_100[:, 52])
# plt.ylim(ymax=2)
plt.xlim(xmin = -1,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(144)
# sns.distplot(clus2_100[:, 41])
sns.distplot(clus2_100[:, 53])
# sns.distplot(clus2_100[:, 52])
# plt.ylim(ymax=.02)
plt.xlim(xmin = -1,xmax=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
clus2_100[:, 53]

# %%
# fig = plt.figure(figsize=(20, 15))
# for i in range(1,41):
#     ax = fig.add_subplot(8, 5, i)
    # plt.plot(samples[:, counter])
# fig = plt.figure(figsize=(20, 5))
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=True)
plt.subplot(131)
sns.distplot(clus2_100[:, 28])
# sns.distplot(clus2_100[:, 31])
# sns.distplot(clus2_100[:, 45])
# sns.distplot(clus2_100n[:, 45])
# sns.distplot(clus1_100nn[:, 45])
plt.ylim(ymax=0.04)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$RIP1trunc$',r'$Necro$', 'c8rip3trunc'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# 
plt.subplot(132)
sns.distplot(clus2_100[:, 29])
# sns.distplot(clus2_100[:, 32])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8af$',r'$rip3f$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(133)
sns.distplot(clus2_100[:, 30])
# sns.distplot(clus2_100[:, 33])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
# plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
x1001 = np.array([0, 30, 90, 270])
x1002 = np.array([480, 720, 960])
y1001 = np.array([0, 0.00885691708746097,0.0161886154261265,0.0373005242261882])
y1002 = np.array([0.2798939020159581, .7797294067, .98])

# %%
m = model100.components

# %%
k = 27

# %%
# tspan = np.linspace(0, 1800, 500)
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nnn = solver6785nnn.run(param_values=clus2_100[k], num_processors = 20)
df1 = result6785nnn.dataframe
# Out:
# 2020-11-09 16:35:36.449 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 16:35:36.460 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 16:35:36.527 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 16:35:36.585 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 16:35:38.317 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 16:35:38.318 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 16:35:38.355 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
# tspan = np.linspace(0, 1800, 500)
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nnn = solver6785nnn.run(param_values=clus2_100, num_processors = 20)
df11 = result6785nnn.dataframe
# Out:
# 2020-11-05 16:47:55.654 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-05 16:47:55.665 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-05 16:47:55.732 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-05 16:47:55.898 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-05 16:49:40.897 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-05 16:49:40.900 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-05 16:49:41.835 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result3528 = solver3528.run(initials = {m.A20(brip = None):0},
                            param_values=clus2_100[k], num_processors = 20)
df2 = result3528.dataframe
# Out:
# 2020-11-09 16:34:37.977 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 16:34:37.989 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 16:34:38.074 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 16:34:38.255 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 16:34:40.125 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 16:34:40.126 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 16:34:40.173 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result3528 = solver3528.run(initials = {m.A20(brip = None):0}
                            , param_values=clus2_100n[k], num_processors = 10)
df3 = result3528.dataframe
# Out:
# 2020-11-09 22:43:10.291 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:43:10.301 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:43:10.369 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:43:10.431 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-09 22:43:11.349 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:43:11.350 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:43:11.387 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus2_100nn[k], num_processors = 10)
df4 = result6785n.dataframe
# Out:
# 2020-11-09 22:43:11.398 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:43:11.403 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:43:11.438 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:43:11.482 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-09 22:43:12.381 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:43:12.383 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:43:12.421 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100nnn[k], num_processors = 10)
df5 = result6785nn.dataframe
# Out:
# 2020-11-09 22:43:12.432 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:43:12.437 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:43:12.471 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:43:12.513 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-09 22:43:13.468 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:43:13.469 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:43:13.507 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100nnnn[k], num_processors = 10)
df6 = result6785nn.dataframe

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result3528 = solver3528.run(initials = {m.CYLD(brip=None, btraf = None):0},
                            param_values=clus2_100[k], num_processors = 10)
df22 = result3528.dataframe
# Out:
# 2020-11-09 16:34:54.756 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 16:34:54.766 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 16:34:54.837 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 16:34:54.902 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-09 16:34:55.873 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 16:34:55.875 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 16:34:55.914 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver3528 = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result3528 = solver3528.run(initials = {m.CYLD(brip=None, btraf = None):0}
                            , param_values=clus2_100n[k], num_processors = 10)
df33 = result3528.dataframe
# Out:
# 2020-11-16 11:35:26.341 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-16 11:35:26.353 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-16 11:35:26.423 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-16 11:35:26.610 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-16 11:35:27.540 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-16 11:35:27.542 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-16 11:35:27.617 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785n = solver6785n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus2_100nn[k], num_processors = 10)
df44 = result6785n.dataframe
# Out:
# 2020-11-16 11:35:27.633 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-16 11:35:27.642 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-16 11:35:27.692 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-16 11:35:27.745 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-16 11:35:28.631 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-16 11:35:28.633 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-16 11:35:28.705 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus2_100nnn[k], num_processors = 10)
df55 = result6785nn.dataframe
# Out:
# 2020-11-16 11:35:28.721 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-16 11:35:28.729 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-16 11:35:28.781 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-16 11:35:28.833 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-11-16 11:35:29.697 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-16 11:35:29.698 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-16 11:35:29.763 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus2_100nnnn[k], num_processors = 10)
df665 = result6785nn.dataframe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-179-48f4910cc7bd> in <module>
# ----> 1 solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
#       2 result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus2_100nnnn[k], num_processors = 10)
#       3 df665 = result6785nn.dataframe
#
# NameError: name 'tspan' is not defined

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan2/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan2/60, df2['MLKLa_obs'].iloc[:]/5544, lw=7, color ='steelblue', label = 'A20KO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan2/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan2/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5,linestyle = '--')
plt.plot(tspan2/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
# plt.grid(False)
plt.savefig('figs/Cluster2/pmlkl_100tnf_clus2_5720_A20KO_w47upratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan2/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan2/60, df2['MLKLa_obs'].iloc[:]/5544, lw=7, color ='steelblue', label = 'A20KO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan2/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan2/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5,linestyle = '--')
plt.plot(tspan2/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.grid(False)
plt.savefig('figs/Cluster2/pmlkl_100tnf_clus2_5720_A20KO_w47upratemodwogrid.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan2/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan2/60, df22['MLKLa_obs'].iloc[:]/5544, lw=7, color ='mediumseagreen', label = 'CYLDKO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan2/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='mediumseagreen', label = 'CYLDx10', zorder = 1, alpha =  5,linestyle = '--')
plt.plot(tspan2/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx100',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan2/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx1000',zorder = 1, alpha =  5, linestyle = '--')
# plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx10000',zorder = 1, alpha =  5,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.grid(False)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w53dwnratemodnogrid.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=7, color ='steelblue', label = 'A20KO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue',zorder = 1, alpha = 5, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_A20KO_w50dwnratemod.pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-4281fd2c9b44> in <module>
#       1 plt.figure(figsize = (8, 6))
# ----> 2 plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
#       3 plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=7, color ='steelblue', label = 'A20KO', zorder = 1, alpha = 5, linestyle = '--')
#       4 plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5, linestyle = '--')
#       5 plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='steelblue', zorder = 1, alpha = 5,linestyle = '--')
#
# NameError: name 'tspan' is not defined

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=6, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w48ratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=8, color ='indianred', label = 'WT', zorder = 2, alpha = 5, linestyle = ':')
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=7, color ='mediumseagreen', label = 'CYLDKO', zorder = 1, alpha = 5, linestyle = '--')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='mediumseagreen', label = 'CYLDx10', zorder = 1, alpha =  5,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx100',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx1000',zorder = 1, alpha =  5, linestyle = '--')
plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='mediumseagreen',  label = 'CYLDx10000',zorder = 1, alpha =  5,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w50dwnratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':') #:
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=6, color ='green', label = 'CYLDKO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4,  color ='green', label = 'CYLDx10', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx100',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx1000',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df665['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx10000',zorder = 1, alpha = 0.7,linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w50dwnratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544,lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=6, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w47upratemod.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=6, color ='black', label = 'WT', zorder = 2, alpha = .8, linestyle = ':') #:
plt.plot(tspan/60, df22['MLKLa_obs'].iloc[:]/5544, lw=6, color ='green', label = 'CYLDKO', zorder = 1, alpha = 1, linestyle = '--')
plt.plot(tspan/60, df33['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green', label = 'CYLDx10', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df44['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx100',zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df55['MLKLa_obs'].iloc[:]/5544, lw=4, color ='green',  label = 'CYLDx1000',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='cyan',  label = 'CYLDx10000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 2', fontsize=17)
plt.savefig('figs/pmlkl_100tnf_clus2_5720_A20KO_w47upratemod.pdf')
plt.show()

# %%
tspan2 = np.linspace(0, 2880, 500)

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100, num_processors = 20)
dfa201 = result6785nn.dataframe
# Out:
# 2020-11-05 16:49:43.664 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-05 16:49:43.669 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-05 16:49:43.705 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-05 16:49:43.845 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-05 16:51:28.189 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-05 16:51:28.192 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-05 16:51:29.124 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100n, num_processors = 20)
df6677 = result6785nn.dataframe
# Out:
# 2020-11-09 22:47:13.295 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:47:13.306 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:47:13.373 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:47:13.547 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 22:48:52.485 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:48:52.487 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:48:53.384 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100nn, num_processors = 20)
df7777 = result6785nn.dataframe
# Out:
# 2020-11-09 22:48:55.154 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:48:55.160 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:48:55.197 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:48:55.347 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 22:50:33.598 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:50:33.600 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:50:34.594 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-1d7da83703e1> in <module>
#       1 plt.figure(figsize = (11,7))
#       2 for n in range(len(clus2_100)):
# ----> 3     plt.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#       4 #     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#       5 plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
#
# NameError: name 'tspan' is not defined

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100nnn, num_processors = 20)
df8888 = result6785nn.dataframe
# Out:
# 2020-11-09 22:50:36.719 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:50:36.724 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:50:36.758 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:50:36.887 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 22:52:17.796 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:52:17.798 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:52:18.815 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus2_100nnnn, num_processors = 12)
df9999 = result6785nn.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus2_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, df667.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.legend(['clus2x1'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 30)
    ax1.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# ax1.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus2_100)):
    ax2.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 30)
    ax2.set_ylim(ymin = 0, ymax = 1)
    ax2.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax2.legend(custom_lines, ['Clus2x2x3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, df888.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')  
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 30)
    ax3.set_ylim(ymin = 0, ymax = 1)
    ax3.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
    ax4.plot(tspan/60, df999.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 30)
    ax4.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus2x4', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of A20 pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df777.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df888.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus2_100, num_processors = 20)
dfcyld1 = result6785nn.dataframe
# Out:
# 2020-11-05 16:56:36.384 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-05 16:56:36.390 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-05 16:56:36.424 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-05 16:56:36.550 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-05 16:58:10.877 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-05 16:58:10.879 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-05 16:58:11.750 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
tspan2 = np.linspace(0, 2880, 500)

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus2_100n, num_processors = 20)
df3333 = result6785nn.dataframe
# Out:
# 2020-11-09 22:52:21.025 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:52:21.030 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:52:21.064 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:52:21.192 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 22:54:00.288 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:54:00.290 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:54:01.337 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nnnn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nnnn = solver6785nnnn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus2_100nn, num_processors = 20)
df4444nn = result6785nnnn.dataframe
# Out:
# 2020-11-09 22:54:03.227 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:54:03.233 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:54:03.269 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:54:03.411 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 22:55:42.548 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:55:42.550 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:55:43.828 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan2, df4444nn.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
# plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan2, df4444n.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
# plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus2_100nnn, num_processors = 20)
df5555 = result6785nn.dataframe
# Out:
# 2020-11-09 22:55:45.665 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-11-09 22:55:45.671 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-11-09 22:55:45.706 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-11-09 22:55:45.842 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 20 processes
# 2020-11-09 22:57:22.729 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-11-09 22:57:22.731 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-11-09 22:57:23.639 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan2, verbose = True)
result6785nn = solver6785nn.run(initials = {m.CYLD(brip=None, btraf = None):0},
                                param_values=clus2_100nnnn, num_processors = 20)
df5566 = result6785nn.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
for n in range(len(clus2_100)):
#     ax1.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax1.plot(tspan/60, df333.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.legend(['clus2x1'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.set_xlim(xmin = 0, xmax = 30)
    ax1.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax1.grid(False)   
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# ax1.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
    
# tspan2 = np.linspace(0, 2160, 300)    
for n in range(len(clus2_100)):
    ax2.plot(tspan/60, df444.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax2.set_xlim(xmin = 0, xmax = 30)
    ax2.set_ylim(ymin = 0, ymax = 1)
    ax2.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax2.legend(custom_lines, ['Clus2x2x3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
#     ax3.vlines(x = 600, ymin = 0, ymax = 5544, linestyle = 'dashed', colors= 'r', zorder = 2, label ='50% pMLKL')
    ax3.plot(tspan/60, df555.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')  
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax3.set_xlim(xmin = 0, xmax = 30)
    ax3.set_ylim(ymin = 0, ymax = 1)
    ax3.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
    
for n in range(len(clus2_100)):
    ax4.plot(tspan/60, df556.loc[n]['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
    ax4.set_xlim(xmin = 0, xmax = 30)
    ax4.set_ylim(ymin = 0, ymax = 1)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    ax4.grid(False)  
#     custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                    Line2D([0], [0], color='red', lw=4)]
#     ax4.legend(custom_lines, ['Clus2x4', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
# plt.plot(tspan/60, dfa20['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of A20 pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df444.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus2_100)):
    plt.plot(tspan/60, df555.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.show()

# %%
dfa20ko = a20ko.dataframe

# %%
dfcyldko = cyldko.dataframe

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 2, alpha = 0.7,marker = 's')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 's')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7, linestyle = '--')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=4, color ='blue',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
plt.legend(['WT', 'A20KO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL Cluster 0', fontsize=17)
# plt.savefig('figs/pmlkl_100tnf_clus0_5720_A20KO_wbindstr.pdf')
plt.show()

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.CYLD(brip=None, btraf = None):0}
                            ,param_values=clus1_100n[k], num_processors = 10)
df7 = result3528.dataframe

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus1_100nn[k], num_processors = 10)
df8 = result6785n.dataframe

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green', label = 'CYLDKO', zorder = 1, alpha = 1, marker = 's')
plt.plot(tspan/60, df7['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green', label = 'CYLDx10m', zorder = 1, alpha = 0.7,linestyle = '--')
plt.plot(tspan/60, df8['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'CYLDx100m',zorder = 1, alpha = 0.7, linestyle = '--')
# plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'CYLDx1000',zorder = 1, alpha = 0.7, linestyle = '--')
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)

plt.legend(['WT', 'CYLDKO'], prop={'size': 14}, loc = 'upper left')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 1', fontsize=17)
plt.show()

# %%
solvercyld = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
resultcyld = solvercyld.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus1_100nn, num_processors = 10)
dfcyld = resultcyld.dataframe

# %%
solvercyld1 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
resultcyld1 = solvercyld1.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus1_100nnn, num_processors = 10)
dfcyld1 = resultcyld1.dataframe

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
    plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
    plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
#     plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
#     plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
    plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
plt.figure(figsize = (11,7))
for n in range(len(clus1_100)):
#     plt.plot(tspan/60, dfcyld.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'green')
    plt.plot(tspan/60, dfcyld1.loc[n]['MLKLa_obs'].iloc[:]/5544, color = 'blue')
plt.show()

# %%
threshold = 4000
threshold2 = 2500

# %%
df_threshtimesc2cyld = dfcyld.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
cluscyld1 = pd.DataFrame({'cyldko': df_threshtimesc2cylx2['MLKLa_obs']})

# %%
dfclus2c2 = pd.DataFrame(data = cluscyld1, columns = ['cyldko'])
dfclus2c2 = pd.melt(dfclus2c2)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"cyldko": "green"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2, zorder=2, palette=my_pal)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.show()

# %%
threshold = 4000

# %%
df_threshtimesc2cylx2nn = df4444nn.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
# df_threshtimesc2a20   = dfa201.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2a20x1 = df6677.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2a20x2 = df7777.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2a20x3 = df8888.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
# df_threshtimesc2a20x4 = df9999.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
df_threshtimesc2wt = df11.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
# df_threshtimesc2cyld = dfcyld1.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2cyldx1= df3333.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
# df_threshtimesc2cylx2 = df4444.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
df_threshtimesc2cylx3 = df5555.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])
# df_threshtimesc2cylx4 = df5566.groupby('simulation').apply(lambda x: (x > threshold).idxmax()).apply(lambda x: [y[1] for y in x])

# %%
clusa20 = pd.DataFrame({'wt': df_threshtimesc2wt['MLKLa_obs'],
                            'a20ko': df_threshtimesc2a20['MLKLa_obs'], 
                          'a20kox1': df_threshtimesc2a20x1['MLKLa_obs'],
                       'a20kox2': df_threshtimesc2a20x2['MLKLa_obs'],
                       'a20kox3': df_threshtimesc2a20x3['MLKLa_obs']})

# %%
dfclus2a = pd.DataFrame(data = clusa20, columns = ['wt', 'a20ko', 'a20kox1', 'a20kox2','a20kox3'])
dfclus2a = pd.melt(dfclus2a)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": "indianred", "a20ko": "steelblue", "a20kox1": "steelblue", 
          "a20kox2": "steelblue", "a20kox3": "steelblue"}
b = sns.swarmplot(x="value", y="variable", data=dfclus2a, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 A20KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.savefig('figs/pmlkl_100tnf_clus2_5720_A20KO_w47upratemod48hr_swarm.pdf')
plt.show()

# %%
cluscyld2nn = pd.DataFrame({'wt': df_threshtimesc2wt['MLKLa_obs'],
                         'CYLDko': df_threshtimesc2cyld['MLKLa_obs'],
                         'CYLDkox1': df_threshtimesc2cyldx1['MLKLa_obs'], 
                          'CYLDkox2nn': df_threshtimesc2cylx2nn['MLKLa_obs'],
                        'CYLDkox3': df_threshtimesc2cylx3['MLKLa_obs']})

# %%
dfclus2c2nn = pd.DataFrame(data = cluscyld2nn, columns = ['wt', 'CYLDko','CYLDkox1', 'CYLDkox2nn','CYLDkox3'])
dfclus2c2nn = pd.melt(dfclus2c2nn)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2nn":"mediumseagreen",
          "CYLDkox3":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2nn, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_w47upratemod48hr_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2":"mediumseagreen",
          "CYLDkox3":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c2, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2880, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_wrip3ratemod_swarm.pdf')
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,10))
my_pal = {"wt": 'indianred',"CYLDko": "mediumseagreen", "CYLDkox1":"mediumseagreen", "CYLDkox2":"mediumseagreen",
          "CYLDkox3":"mediumseagreen", "CYLDkox4":"mediumseagreen"}
# b = sns.boxplot(x = "value", y ="variable", data = dfclus0, notch = True, width = 0.5, palette = my_pal)
b = sns.swarmplot(x="value", y="variable", data=dfclus2c, zorder=2, palette=my_pal, alpha = 1)
b.set_xlabel("Time (minutes)",fontsize=15)
b.set_ylabel("Cluster 2 CYLD KO",fontsize=15)
b.tick_params(labelsize=15)
plt.xlim(xmax = 2800, xmin = 0)
# plt.savefig('figs/pmlkl_100tnf_clus0box_wswarm_5720_mod.pdf')
# plt.savefig('figs/pmlkl_100tnf_clus2_5720_CYLDKO_wrip3ratemod_swarm.pdf')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
# plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KOx10', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df7['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue',  label = 'A20KOx100',zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df8['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'A20KOx1000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 0', fontsize=17)
plt.show()

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[21], num_processors = 10)
df2n = result6785n.dataframe

# %%
plt.figure()
plt.plot(tspan/60, df2n['MLKLa_obs'].iloc[:], lw=1.5, color ='blue', zorder = 1, alpha = 0.5)
plt.show()

# %%
solvercyld2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
cyldclus2 = solvercyld2.run(initials = { m.CYLD(brip=None, btraf = None):0},
                         param_values=clus2_100, num_processors = 20)

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
k = 2211

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(param_values=clus0_100[k], num_processors = 10)
df11 = result3528.dataframe

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[k], num_processors = 10)
df1n = result3528n.dataframe

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus0_100[k],
                              num_processors = 10)
df1nn = result3528n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df11['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
solver6785 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785 = solver6785.run(param_values=par_files[6785], num_processors = 10)
df2 = result6785.dataframe

# %%
solver5420 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420 = solver5420.run(param_values=par_files[5420], num_processors = 10)
df3 = result5420.dataframe

# %%
solver4230 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230 = solver4230.run(param_values=par_files[4230], num_processors = 10)
df4 = result4230.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
m = model100.components

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=par_files[6785], num_processors = 10)
df2n = result6785n.dataframe

# %%
solver5420n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420n = solver5420n.run(initials = {m.A20(brip = None):0},param_values=par_files[5420], num_processors = 10)
df3n = result5420n.dataframe

# %%
solver4230n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230n = solver4230n.run(initials = {m.A20(brip = None):0},param_values=par_files[4230], num_processors = 10)
df4n = result4230n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()
