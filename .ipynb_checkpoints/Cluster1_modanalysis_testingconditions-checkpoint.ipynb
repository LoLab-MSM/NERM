# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
for i,pr in enumerate(model100.parameters):
    print(i,":",pr)
# Out:
# 0 : Parameter('TNF_0', 2326.0)
# 1 : Parameter('TNFR_0', 4800.0)
# 2 : Parameter('TRADD_0', 4696.0)
# 3 : Parameter('RIP1_0', 40000.0)
# 4 : Parameter('TRAF_0', 11776.0)
# 5 : Parameter('cIAP_0', 9000.0)
# 6 : Parameter('A20_0', 9000.0)
# 7 : Parameter('CYLD_0', 9000.0)
# 8 : Parameter('FADD_0', 3109.0)
# 9 : Parameter('flip_L_0', 3900.0)
# 10 : Parameter('Lubac_0', 7226.0)
# 11 : Parameter('C8_0', 3799.0)
# 12 : Parameter('RIP3_0', 10654.0)
# 13 : Parameter('MLKLa_0', 5544.0)
# 14 : Parameter('p1f', 1e-06)
# 15 : Parameter('p1r', 0.001)
# 16 : Parameter('p2f', 0.001)
# 17 : Parameter('p3f', 1e-06)
# 18 : Parameter('p3r', 0.001)
# 19 : Parameter('p4f', 1e-06)
# 20 : Parameter('p4r', 0.001)
# 21 : Parameter('p5f', 1e-06)
# 22 : Parameter('p5r', 0.001)
# 23 : Parameter('p6f', 1e-06)
# 24 : Parameter('p6r', 0.001)
# 25 : Parameter('p7f', 0.1)
# 26 : Parameter('p8f', 1e-06)
# 27 : Parameter('p8r', 0.001)
# 28 : Parameter('p9f', 1e-06)
# 29 : Parameter('p9r', 0.001)
# 30 : Parameter('p10f', 0.1)
# 31 : Parameter('p11f', 1e-06)
# 32 : Parameter('p11r', 0.001)
# 33 : Parameter('p12f', 0.1)
# 34 : Parameter('p13f', 0.1)
# 35 : Parameter('p13r', 3.11e-07)
# 36 : Parameter('p14f', 3.27e-06)
# 37 : Parameter('p14r', 0.018)
# 38 : Parameter('p15f', 3.27e-06)
# 39 : Parameter('p15r', 0.018)
# 40 : Parameter('p16f', 0.0327)
# 41 : Parameter('p16r', 0.018)
# 42 : Parameter('p17f', 1e-06)
# 43 : Parameter('p18f', 1e-06)
# 44 : Parameter('p18r', 0.001)
# 45 : Parameter('p19f', 0.1)
# 46 : Parameter('p20f', 0.01)
# 47 : Parameter('p20r', 0.001)
# 48 : Parameter('p21f', 0.001)
# 49 : Parameter('p22f', 1e-06)
# 50 : Parameter('p23f', 1.0)
# 51 : Parameter('p24f', 1e-06)
# 52 : Parameter('p24r', 0.001)
# 53 : Parameter('p25f', 1e-06)

# %%
par_files = np.load('necro_pars10k_allclusmod.npy')

# %%
clus0_100 = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus0_100n = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus0_100nn = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus1_100 = np.load('necro_pars10k_cluster1_5720_mod.npy')
clus2_100 = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus3_100 = np.load('necro_pars10k_cluster3_5720_mod.npy')

# %%
print(clus0_100[:][:,48])
# Out:
# [1.54165300e-02 6.15061267e-05 3.22080475e-05 ... 1.94433744e-04
#  1.11814462e-04 2.51747459e-04]

# %%
clus0_100n[:][:,48] = clus0_100n[:][:,48]*10

# %%
clus0_100n[:][:,48]
# Out:
# array([0.1541653 , 0.00061506, 0.00032208, ..., 0.00194434, 0.00111814,
#        0.00251747])

# %%
clus0_100nn[:][:,48] = clus0_100nn[:][:,48]*100

# %%
clus0_100nn[:][:,48]
# Out:
# array([1.541653  , 0.00615061, 0.0032208 , ..., 0.01944337, 0.01118145,
#        0.02517475])

# %%
clus0_100nnn = np.load('necro_pars10k_cluster0_5720_mod.npy')

# %%
clus0_100nnn[:][:,48] = clus0_100nnn[:][:,48]*1000

# %%
# fig = plt.figure(figsize=(20, 15))
# for i in range(1,41):
#     ax = fig.add_subplot(8, 5, i)
    # plt.plot(samples[:, counter])
# fig = plt.figure(figsize=(20, 5))
fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=True)
plt.subplot(131)
# sns.distplot(clus0_100[:, 42])
sns.distplot(clus0_100[:, 48])
# sns.distplot(clus0_100[:, 45])
# plt.ylim(ymax=0.3)
# plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub + A20/CYLD -> RIP1ub:A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=20)
plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4),
               Line2D([0], [0], color='red', lw=4)]
plt.legend(custom_lines, [r'$RIP1trunc$',r'$Necro$', 'c8rip3trunc'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)

plt.subplot(132)
sns.distplot(clus0_100[:, 40])
sns.distplot(clus0_100[:, 46])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20 -> RIP1ub + A20/CYLD', fontsize=15)
plt.xlabel("Log(10) Value", fontsize=20)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, [r'$c8af$',r'$rip3f$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
plt.subplot(133)
sns.distplot(clus0_100[:, 41])
sns.distplot(clus0_100[:, 47])
# plt.ylim(ymax=0.3)
plt.xlim(xmin = -10,xmax=10)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(np.arange(-10, 11, 5))
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
# plt.title('RIP1ub:A20/CYLD -> RIP1deub + A20/CYLD',fontsize=15)
# plt.xlabel("Log(10) Value", fontsize=17)
# plt.ylabel("Probability", fontsize=20, labelpad=15)
custom_lines = [Line2D([0], [0], color='blue', lw=4),
                Line2D([0], [0], color='orange', lw=4)]
plt.legend(custom_lines, [r'$c8ar$',r'$rip3r$'], prop={'size': 15}, loc = 'best')
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.6)
# plt.text(0.5, 0.04, 'common X', ha='center')
# plt.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
# plt.xlabel("Log(10) Value", fontsize=14)
# plt.ylabel("Probability", fontsize=14, labelpad=15)
# plt.savefig('updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf', format='pdf')
# plt.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
# fig.savefig("updatedkos/necro_5720_pydream_posta20cyldpardists_allchains5.pdf")
plt.show()

# %%
x1001 = np.array([0, 30, 90, 270])
x1002 = np.array([480, 720, 960])
y1001 = np.array([0, 0.00885691708746097,0.0161886154261265,0.0373005242261882])
y1002 = np.array([0.2798939020159581, .7797294067, .98])

# %%
m = model100.components

# %%
k = 557

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.C8(bf=None, flip = None, state='I'): 0,m.flip_L(bDED=None, state = 'A'):0,
            m.A20(brip = None):0, m.RIP3(bRHIM=None, bDD = None, state='unmod'): 10654000,
            m.RIP1(bscf=None, btraf=None, bub1=None, bub2=None, bub3=None, bDD = None, bRHIM = None, bMLKL = None, state='unmod'):400000},
            param_values=clus0_100[k], num_processors = 10)
df8 = result3528.dataframe
# Out:
# 2020-10-22 11:48:48.129 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-22 11:48:48.141 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-22 11:48:48.216 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-22 11:48:48.289 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-22 11:48:48.464 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-22 11:48:48.466 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-22 11:48:48.526 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.A20(brip = None):0, m.RIP3(bRHIM=None, bDD = None, state='unmod'): 1065400}, param_values=clus0_100[k], num_processors = 10)
df6 = result3528.dataframe
# Out:
# 2020-10-22 11:36:21.735 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-22 11:36:21.746 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-22 11:36:21.818 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-22 11:36:21.884 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-22 11:36:22.067 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-22 11:36:22.068 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-22 11:36:22.125 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(initials = {m.A20(brip = None):0, m.RIP3(bRHIM=None, bDD = None, state='unmod'): 10654000}, param_values=clus0_100[k], num_processors = 10)
df7 = result3528.dataframe
# Out:
# 2020-10-22 11:36:22.138 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-22 11:36:22.145 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-22 11:36:22.189 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-22 11:36:22.234 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-22 11:36:22.403 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-22 11:36:22.405 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-22 11:36:22.464 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus0_100n[k], num_processors = 10)
df2 = result6785n.dataframe
# Out:
# 2020-10-21 15:25:06.946 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:25:06.955 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:25:07.027 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:25:07.122 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-21 15:25:07.455 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:25:07.457 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:25:07.529 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nn = solver6785nn.run(initials = {m.A20(brip = None):0},param_values=clus0_100nn[k], num_processors = 10)
df3 = result6785nn.dataframe
# Out:
# 2020-10-21 15:25:07.547 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:25:07.556 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:25:07.647 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:25:07.754 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-21 15:25:08.152 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:25:08.153 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:25:08.237 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnn = solver6785nnn.run(param_values=clus0_100[k], num_processors = 10)
df4 = result6785nnn.dataframe
# Out:
# 2020-10-21 15:25:08.255 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:25:08.265 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:25:08.347 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:25:08.450 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-21 15:25:08.990 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:25:08.992 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:25:09.076 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver6785nnn = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785nnn = solver6785nnn.run(initials = {m.A20(brip = None):0},param_values=clus0_100nnn[k], num_processors = 10)
df5 = result6785nnn.dataframe
# Out:
# 2020-10-21 15:27:02.210 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:27:02.219 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:27:02.293 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:27:02.387 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-21 15:27:02.792 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:27:02.794 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:27:02.876 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
plt.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df2['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KOx10', zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue',  label = 'A20KOx100',zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue',  label = 'A20KOx1000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 0', fontsize=17)
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1, color ='red', label = 'WT', zorder = 1, alpha = 0.7,marker = 's')
# plt.plot(tspan/60, df5['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KO', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df6['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', label = 'A20KOx10', zorder = 1, alpha = 1, marker = 'x')
# plt.plot(tspan/60, df7['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue',  label = 'A20KOx100',zorder = 1, alpha = 1, marker = 'x')
plt.plot(tspan/60, df8['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='green',  label = 'A20KOx1000',zorder = 1, alpha = 0.7, marker = 'x')
# plt.errorbar(x1001/60, y1001,
#              yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
#              (.07,.07,.07,.07)],
#                    fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
# plt.errorbar(x1002/60, y1002,
#              yerr= .07, fmt='.k', ecolor ='black', alpha = 0.75, zorder = 2)
plt.xlim(xmin = 0, xmax = 30)
plt.ylim(ymax = 1.01)
# custom_lines = [Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='blue', lw=4),
#                Line2D([0], [0], color='purple', lw=4),
#                 Line2D([0], [0], color='blue', lw=4)]
# plt.legend( prop={'size': 12}, loc = 'best')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Time (hours)', fontsize=18)
plt.ylabel('Amount pMLKL (normalized) Cluster 0', fontsize=17)
plt.show()

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[21], num_processors = 10)
df2n = result6785n.dataframe
# Out:
# 2020-10-21 10:59:35.657 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 10:59:35.668 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 10:59:35.741 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 10:59:35.803 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-21 10:59:36.011 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 10:59:36.012 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 10:59:36.063 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
plt.figure()
plt.plot(tspan/60, df2n['MLKLa_obs'].iloc[:], lw=1.5, color ='blue', zorder = 1, alpha = 0.5)
plt.show()

# %%
solvercyld2 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
cyldclus2 = solvercyld2.run(initials = { m.CYLD(brip=None, btraf = None):0},
                         param_values=clus2_100, num_processors = 20)

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
k = 2211

# %%
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(param_values=clus0_100[k], num_processors = 10)
df11 = result3528.dataframe
# Out:
# 2020-10-21 15:24:29.097 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:24:29.106 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:24:29.173 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:24:29.255 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-21 15:24:29.760 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:24:29.761 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:24:29.836 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.A20(brip = None):0},param_values=clus0_100[k], num_processors = 10)
df1n = result3528n.dataframe
# Out:
# 2020-10-21 15:24:29.858 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:24:29.868 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:24:29.951 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:24:30.055 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# running simulations 10
# 2020-10-21 15:24:30.367 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:24:30.369 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:24:30.453 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.CYLD(brip=None, btraf = None):0},param_values=clus0_100[k],
                              num_processors = 10)
df1nn = result3528n.dataframe
# Out:
# 2020-10-21 15:24:30.475 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-21 15:24:30.485 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-21 15:24:30.574 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-21 15:24:30.673 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# running simulations 10
# 2020-10-21 15:24:31.175 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-21 15:24:31.176 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-21 15:24:31.265 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (20,5))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df11['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df1n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df1nn['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')

 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 13)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
solver6785 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785 = solver6785.run(param_values=par_files[6785], num_processors = 10)
df2 = result6785.dataframe
# Out:
# 2020-10-19 20:14:41.358 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 20:14:41.363 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-c347a7d99267> in <module>
#       1 solver6785 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
# ----> 2 result6785 = solver6785.run(param_values=par_files[6785], num_processors = 10)
#       3 df2 = result6785.dataframe
#
# NameError: name 'par_files' is not defined

# %%
solver5420 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420 = solver5420.run(param_values=par_files[5420], num_processors = 10)
df3 = result5420.dataframe

# %%
solver4230 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230 = solver4230.run(param_values=par_files[4230], num_processors = 10)
df4 = result4230.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
m = model100.components

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=par_files[6785], num_processors = 10)
df2n = result6785n.dataframe

# %%
solver5420n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420n = solver5420n.run(initials = {m.A20(brip = None):0},param_values=par_files[5420], num_processors = 10)
df3n = result5420n.dataframe

# %%
solver4230n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230n = solver4230n.run(initials = {m.A20(brip = None):0},param_values=par_files[4230], num_processors = 10)
df4n = result4230n.dataframe

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()
