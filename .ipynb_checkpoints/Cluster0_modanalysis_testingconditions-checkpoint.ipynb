# %%
from necro_uncal_new_updated import model as model100
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# from necro_pydream_model_file_8920 import model
from pysb.simulator import ScipyOdeSimulator
import numpy as np
from scipy.stats import norm,uniform
import seaborn as sns
from matplotlib import pyplot as plt
import random
import os
from pylab import *
from pysb.core import *
from pysb.bng import *
from pysb.integrate import *
import matplotlib.pyplot as plt
import numpy as np
from pysb.util import alias_model_components
from scipy import stats
from pysb.simulator import SimulationResult
import pandas as pd
import seaborn as sns

# %%
par_files = np.load('necro_pars10k_allclusmod.npy')

# %%
clus0_100 = np.load('necro_pars10k_cluster0_5720_mod.npy')
clus1_100 = np.load('necro_pars10k_cluster1_5720_mod.npy')
clus2_100 = np.load('necro_pars10k_cluster2_5720_mod.npy')
clus3_100 = np.load('necro_pars10k_cluster3_5720_mod.npy')

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528 = solver3528.run(param_values=clus0_100[0], num_processors = 10)
df1 = result3528.dataframe
# Out:
# 2020-10-19 17:45:02.999 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:45:03.011 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:45:03.082 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:45:03.142 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# running simulations 10
# 2020-10-19 17:45:03.400 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:45:03.401 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:45:03.465 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.A20(brip = None):0},param_values=par_files[3528], num_processors = 10)
df1n = result3528n.dataframe
# Out:
# 2020-10-19 17:46:59.917 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:46:59.928 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:46:59.999 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:47:00.063 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# running simulations 10
# 2020-10-19 17:47:00.297 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:47:00.299 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:47:00.333 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
print('running simulations 10')
tspan = np.linspace(0, 1800, 500)
solver3528n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result3528n = solver3528n.run(initials = {m.A20(brip = None):0},param_values=par_files[3528], num_processors = 10)
df1n = result3528n.dataframe

# %%
solver6785 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785 = solver6785.run(param_values=par_files[6785], num_processors = 10)
df2 = result6785.dataframe
# Out:
# 2020-10-19 17:45:03.479 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:45:03.486 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:45:03.534 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:45:03.581 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-19 17:45:03.759 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:45:03.760 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:45:03.958 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver5420 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420 = solver5420.run(param_values=par_files[5420], num_processors = 10)
df3 = result5420.dataframe
# Out:
# 2020-10-19 17:45:03.967 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:45:03.972 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:45:04.007 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:45:04.046 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-19 17:45:04.179 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:45:04.180 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:45:04.236 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver4230 = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230 = solver4230.run(param_values=par_files[4230], num_processors = 10)
df4 = result4230.dataframe
# Out:
# 2020-10-19 17:45:04.248 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:45:04.254 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:45:04.298 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:45:04.343 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-19 17:45:04.643 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:45:04.646 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:45:04.721 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
x1001 = np.array([0, 30, 90, 270])
x1002 = np.array([480, 720, 960])
y1001 = np.array([0, 0.00885691708746097,0.0161886154261265,0.0373005242261882])
y1002 = np.array([0.2798939020159581, .7797294067, .98])

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()

# %%
m = model100.components

# %%
solver6785n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result6785n = solver6785n.run(initials = {m.A20(brip = None):0},param_values=par_files[6785], num_processors = 10)
df2n = result6785n.dataframe
# Out:
# 2020-10-19 17:47:00.343 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:47:00.348 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:47:00.382 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:47:00.421 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-19 17:47:00.583 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:47:00.585 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:47:00.635 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver5420n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result5420n = solver5420n.run(initials = {m.A20(brip = None):0},param_values=par_files[5420], num_processors = 10)
df3n = result5420n.dataframe
# Out:
# 2020-10-19 17:47:00.647 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:47:00.653 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:47:00.696 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:47:00.740 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-19 17:47:00.867 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:47:00.868 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:47:00.905 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
solver4230n = ScipyOdeSimulator(model100, tspan=tspan, verbose = True)
result4230n = solver4230n.run(initials = {m.A20(brip = None):0},param_values=par_files[4230], num_processors = 10)
df4n = result4230n.dataframe
# Out:
# 2020-10-19 17:47:00.914 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Simulator created
# 2020-10-19 17:47:00.919 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Equation mode set to "cython"
# 2020-10-19 17:47:00.953 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] Simulation(s) started
# 2020-10-19 17:47:00.992 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] Multi-processor (parallel) mode using 10 processes
# 2020-10-19 17:47:01.215 - pysb.simulator.scipyode - INFO - [necro_uncal_new_updated] All simulation(s) complete
# 2020-10-19 17:47:01.217 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor started
# 2020-10-19 17:47:01.268 - pysb.simulator.scipyode - DEBUG - [necro_uncal_new_updated] SimulationResult constructor finished

# %%
import matplotlib
matplotlib.rc('xtick', labelsize=14) 
matplotlib.rc('ytick', labelsize=14) 
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize = (15,10))
# tspan = np.linspace(0, 1440, 300)
ax1.plot(tspan/60, df1n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax1.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax1.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.legend(['clus0'], loc = 'best', fontsize = 14)
#     plt.ylim(ymax = 5544, ymin =0)
#     plt.xlim(xmax = 1440, xmin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.set_xlim(xmin = 0, xmax = 24)
ax1.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax1.grid(False)   
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax1.legend(custom_lines, ['Clus0', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax2.plot(tspan/60,df2n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax2.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax2.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax2.set_xlim(xmin = 0, xmax = 24)
ax2.set_ylim(ymin = 0)
ax2.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax2.legend(custom_lines, ['Clus1', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    

ax3.plot(tspan/60, df3n['MLKLa_obs'].iloc[:]/5544,lw=1.5, color ='blue', zorder = 1, alpha = 0.3)  
ax3.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax3.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax3.set_xlim(xmin = 0, xmax = 24)
ax3.set_ylim(ymin = 0)
ax3.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax3.legend(custom_lines, ['Clus2', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
    
ax4.plot(tspan/60, df4n['MLKLa_obs'].iloc[:]/5544, lw=1.5, color ='blue', zorder = 1, alpha = 0.3)
ax4.errorbar(x1001/60, y1001,
             yerr=[(0, 0.00885691708746097,0.0161886154261265,0.0373005242261882),
             (.07,.07,.07,.07)],
                   fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
ax4.errorbar(x1002/60, y1002,
             yerr= .07, fmt='.k', ecolor ='red', alpha = 0.75, zorder = 2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#     plt.xlabel("Time (in hr)", fontsize=15)
#     plt.ylabel("Amount (normalized)", fontsize=15)
ax4.set_xlim(xmin = 0, xmax = 24)
ax4.set_ylim(ymin = 0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
ax4.grid(False)  
custom_lines = [Line2D([0], [0], color='blue', lw=4),
               Line2D([0], [0], color='red', lw=4)]
ax4.legend(custom_lines, ['Clus3', 'pMLKL Data'], prop={'size': 12}, loc = 'best')
 
fig.text(0.5, 0.04, 'Time (Hours)', ha='center', va='center',fontsize = 16)
fig.text(0.06, 0.5, 'Amount of Flip pMLKL under 100 ng/ml TNF(Normalized)',
         ha='center', va='center', rotation='vertical', fontsize = 16)
# plt.savefig('pmlkl_100tnf_4clus_5720_A20KO.pdf')
plt.show()
